# %%
from soil.agents import FSM, state, default_state
from soil import Environment
from random import random, shuffle, sample
from itertools import islice
import logging
from enum import Enum
from random import randint
from soil import simulation
from soil import *
import soil
import networkx as nx
import matplotlib.pyplot as plt
import logging
import random
import numpy
logging.basicConfig()
# Out:
# /usr/lib/python3.5/importlib/_bootstrap.py:222: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)
# /usr/lib/python3.5/importlib/_bootstrap.py:222: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)

# %%
class Genders(Enum):
    male = 'male'
    female = 'female'

class Venues(Enum):
    pub = 'pub'
    disco = 'disco'
    street = 'street'


class CityPubs(Environment):
  
    level = logging.INFO

    def __init__(self, *args, number_of_pubs=3, number_of_discos=3, number_of_street=3, **kwargs):
                   
                    super(CityPubs, self).__init__(*args, **kwargs)  #Para la clase superior. Constructor super.
                    pubs = {}
                    for i in range(number_of_pubs):
                        newpub = {
                            'name': 'The awesome pub #{}'.format(i),
                            'open': False,
                            'capacity': numpy.random.normal(100,20),
                            'occupancy': 0,
                            'price':randint(5, 8),
                            'type': Venues.pub.value,
                            'entry': 0,
                            'opening_time': 1,
                            'closing_time': randint(20,24),
                        }
                        pubs[newpub['name']] = newpub
                    for i in range(number_of_discos):
                        newpub = {
                            'name': 'The awesome disco #{}'.format(i),
                            'open': False,
                            'capacity': numpy.random.normal(1300,300) ,
                            'occupancy': 0,
                            'price':randint(7, 12),
                            'type': Venues.disco.value,
                            'entry': randint(15,20),
                            'opening_time': 10, #ES el10!!
                            'closing_time': randint(32,36),
                        }
                        pubs[newpub['name']] = newpub
                    for i in range(number_of_street):
                        newpub = {
                            'name': 'The awesome street #{}'.format(i),
                            'open': False,
                            'capacity': 10000 ,
                            'occupancy': 0,
                            'price':randint(2,5),
                            'type': Venues.street.value,
                            'entry': 0,
                            'opening_time': 1,
                            'closing_time': 39,
                        }
                        pubs[newpub['name']] = newpub
            
                        
                    self['pubs'] = pubs




    def return_open (self,pub_name):
        pub = self['pubs'][pub_name]
        return pub['open']

    def return_occupancy (self,pub_name):
        pub = self['pubs'][pub_name]
        return pub['occupancy']

    def return_price(self,pub_name):
        pub = self['pubs'][pub_name]
        return pub['price']

    def return_name(self,pub_name):
        pub = self['pubs'][pub_name]
        return pub['name']

    def return_type(self,pub_name):
        if pub_name==None:
            return None
        pub = self['pubs'][pub_name]
        return pub['type']

    def return_opening_time(self,pub_name):
        pub = self['pubs'][pub_name]
        return pub['opening_time']

    def return_closing_time(self,pub_name):
        pub = self['pubs'][pub_name]
        return pub['closing_time']

    def set_open(self,pub_name):
        pub = self['pubs'][pub_name]
        pub['open'] = True

    def set_close(self,pub_name):
        pub = self['pubs'][pub_name]
        pub['open'] = False

    def set_capacity(self,pub_name, number):
        pub = self['pubs'][pub_name]
        pub['capacity'] = number  

    def set_occupancy(self,pub_name, number):
        pub = self['pubs'][pub_name]
        pub['occupancy'] = number  

    def set_price(self,pub_name, number):
        pub = self['pubs'][pub_name]
        pub['price'] = number  

    def set_closing_time(self,pub_name, number):
        pub = self['pubs'][pub_name]
        pub['closing_time'] = number  

    def set_entry (self,pub_name, number):
        pub = self['pubs'][pub_name]
        pub['entry'] = number  



    def enter(self, pub_name, *nodes):

        '''Agents will try to enter. The pub checks if it is possible'''
    
        try:
            pub = self['pubs'][pub_name]
        except KeyError:
            raise ValueError('Pub {} is not available'.format(pub_name))

        for node in nodes:
            if not pub['open'] or (pub['capacity'] < (len(nodes) + pub['occupancy'])) or node['money']< pub['entry']:

                return False

        pub['occupancy'] += len(nodes)
        for node in nodes:
            node['pub'] = pub_name
            node['money'] = node['money'] - pub['entry']


        #El líder hace un link con el bar en cuestión self.env.add_edge(self, pub)
        return True

    def available_pubs_total(self):
        available_venues = []
        for pub in self['pubs'].values():
            if pub['open'] and (pub['occupancy'] < pub['capacity']):
                available_venues.append(pub['name'])

        shuffle(available_venues)
        return available_venues 

    def available_pubs(self):
        available_venues = []
        for pub in self['pubs'].values():
            if pub['open'] and (pub['occupancy'] < pub['capacity']) and pub['type'] == "pub":
                available_venues.append(pub['name'])

        shuffle(available_venues)
        return available_venues 

    def available_discos(self):
        available_venues = []
        for pub in self['pubs'].values():
            if pub['open'] and (pub['occupancy'] < pub['capacity']) and pub['type'] == "disco":
                available_venues.append(pub['name'])

        shuffle(available_venues)
        return available_venues 

    def available_street(self):
        available_venues = []
        for pub in self['pubs'].values():
            if pub['open'] and (pub['occupancy'] < pub['capacity']) and pub['type'] == "street":
                available_venues.append(pub['name'])

        shuffle(available_venues)
        return available_venues 

    def get_venues(self):

        venues = []
        for venue in self['pubs'].values():
            venues.append(venue['name'])
        return venues 

    def reelect_leader(self,*group):
        for node in group:
            node['is_leader']=True
            return
        #Hace un link al bar donde estén



    #Un grupo se va de un pub. La sintaxis "del" es como decir que te vacíe esa variable
    """def exit(self, pub_id, *node_ids):
                    '''Agents will notify the pub they want to leave'''
                    try:
                        pub = self['pubs'][pub_id]
                    except KeyError:
                        raise ValueError('Pub {} is not available'.format(pub_id))
                    for node_id in node_ids:
                        node = self.get_agent(node_id)
                        if pub_id == node['pub']:
                            del node['pub']
                            pub['occupancy'] -= 1
            
                def exit(self, pub_id, *nodes):
                    '''Agents will notify the pub they want to leave'''
                    try:
                        pub = self['pubs'][pub_id]
                    except KeyError:
                        raise ValueError('Pub {} is not available'.format(pub_id))
                    for node in nodes:
                     
                        if pub_id == node['pub']:
                            del node['pub']
                            pub['occupancy'] -= 1
            """
    def exit(self, pub_name, *nodes):

        try:
            pub = self['pubs'][pub_name]
        except KeyError:
            raise ValueError('Pub {} is not available'.format(pub_name))
        
        pub['occupancy'] -= len(nodes)

# %%
class Patron(FSM):
  
    level = logging.INFO

    defaults = {
        'pub': None,
        'drunk': False,
        'pints': 0,
        'max_pints': 5,
        'in_a_group':False,
        'money':20,
        'is_leader': False,
        'group_size':0,
        'num_of_changes':0,
        'intoxicated': False,
        'going_out_time':10,
        'coming_back_time':16,
        'group_size':0,
        'prob_fight':0,
        'num_of_fights':0,
        'in_a_fight':False,

    }

    @default_state
    @state
    def setting_parameters(self):

    
        '''Setting max_pints'''
        if self['age']==15:
            if self['gender']=="female":
                self['max_pints']=numpy.random.normal(3,0.5)
            else:
                self['max_pints']=numpy.random.normal(4,1)

        elif self['age']==20:
            if self['gender']=="female":
                self['max_pints']=numpy.random.normal(4,1)
            else:
                self['max_pints']=numpy.random.normal(6,1)

        else:
            if self['gender']=="female":
                self['max_pints']=numpy.random.normal(4,1)
            else:
                self['max_pints']=numpy.random.normal(6,1)



        '''Setting intoxication_drinkthreshold'''
        self['intoxication_drinkthreshold'] = 2*self['max_pints']
        
        '''Setting money'''
        if self['age']==15:
            if self['gender']=="female":
                self['money']=numpy.random.normal(25,3)
            else:
                self['money']=numpy.random.normal(25,5)

        elif self['age']==20:
            if self['gender']=="female":
                self['money']=numpy.random.normal(35,7)
            else:
                self['money']=numpy.random.normal(40,7)

        else:
            if self['gender']=="female":
                self['money']=numpy.random.normal(60,10)
            else:
                self['money']=numpy.random.normal(65,15)



        
        r = random()

        '''Setting coming_back_time'''


        if self['age']==15:

            if r<0.163:
                self['coming_back_time'] = randint(6,9)
                                                
            elif r<0.299:
                                    
                self['coming_back_time'] = randint(10,13)
                                                    
            elif r<0.407:
                                    
                self['coming_back_time'] = randint(14,17)

            elif r<0.543:
                                    
                self['coming_back_time'] = randint(18,21)


            elif r<0.67:
                                    
                self['coming_back_time'] = randint(22,25)

            elif r<0.771:
                                    
                self['coming_back_time'] = randint(26,29)

            elif r<0.863:
                                    
                self['coming_back_time'] = randint(30,33)

            elif r<0.932:
                                    
                self['coming_back_time'] = randint(34,37)

            elif r<0.965:
                                    
                self['coming_back_time'] = randint(38,42)

            else:

                self['coming_back_time'] = randint(6,42)

        elif self['age']==20:

            if r<0.078:
                self['coming_back_time'] = randint(6,9)
                                                
            elif r<0.152:
                                    
                self['coming_back_time'] = randint(10,13)
                                                    
            elif r<0.253:
                                    
                self['coming_back_time'] = randint(14,17)

            elif r<0.409:
                                    
                self['coming_back_time'] = randint(18,21)


            elif r<0.581:
                                    
                self['coming_back_time'] = randint(22,25)

            elif r<0.709:
                                    
                self['coming_back_time'] = randint(26,29)

            elif r<0.811:
                                    
                self['coming_back_time'] = randint(30,33)

            elif r<0.915:
                                    
                self['coming_back_time'] = randint(34,37)

            elif r<0.966:
                                    
                self['coming_back_time'] = randint(38,42)

            else:

                self['coming_back_time'] = randint(6,42)

        else:

            if r<0.082:
                self['coming_back_time'] = randint(6,9)
                                                
            elif r<0.163:
                                    
                self['coming_back_time'] = randint(10,13)
                                                    
            elif r<0.266:
                                    
                self['coming_back_time'] = randint(14,17)

            elif r<0.451:
                                    
                self['coming_back_time'] = randint(18,21)


            elif r<0.604:
                                    
                self['coming_back_time'] = randint(22,25)

            elif r<0.724:
                                    
                self['coming_back_time'] = randint(26,29)

            elif r<0.819:
                                    
                self['coming_back_time'] = randint(30,33)

            elif r<0.908:
                                    
                self['coming_back_time'] = randint(34,37)

            elif r<0.942:
                                    
                self['coming_back_time'] = randint(38,42)

            else:

                self['coming_back_time'] = randint(6,42)

                                    
    
        return self.looking_for_friends



    
    @state
    def looking_for_friends(self):
     
        #ARREGLAR QUE NO ESPERAN LOS PASOS PARA SALIR! Problema de soil, no funcion el self.env.timeout
        

        if(self['in_a_group'] == False):
            self.info('I am looking for friends')
            self['is_leader'] = True
 
            available_friends = list(self.get_agents(drunk=False,
                                                     pub=None,
                                                     in_a_group=False,
                                                     age=self['age']))
                                                     
            if not available_friends or len(available_friends)==1:
                self.info('Life sucks and I\'m alone!')
                return self.at_home

            befriended = self.try_friends(available_friends)
            if befriended:

                group = list(self.get_neighboring_agents())


                r=random()
                if self['age']==15:
                    if(r<0.3963):
                        going_out_time = 2
                    elif(r<(0.3963+0.2642)):
                        going_out_time = randint(3,6)
                    elif(r<(0.3963+0.2642+0.2642)):
                        going_out_time = randint(7,10)
                    else:
                        going_out_time = randint(11,18)

                elif self['age']==20:
                    if(r<0.1519):
                        going_out_time = 2
                    elif(r<(0.1519+0.2658)):
                        going_out_time = randint(3,6)
                    elif(r<(0.1519+0.2658+0.4937)):
                        going_out_time = randint(7,10)
                    else:
                        going_out_time = randint(11,18)

                else:
                    if(r<0.2041):
                        going_out_time = 2
                    elif(r<(0.2041+0.449)):
                        going_out_time = randint(3,6)
                    elif(r<(0.2041+0.449+0.2653)):
                        going_out_time = randint(7,10)
                    else:
                        going_out_time = randint(11,18)

                for friend in group:
                    friend['going_out_time']= going_out_time
                    friend['group_size'] = len(group) +1
                    
               
                self['going_out_time'] = going_out_time
                self['group_size'] =  len(group)+1          
                
                return self.looking_for_pub, self.env.timeout(self['going_out_time']-self.now) 
        else:
            self.debug('{} has a group already' .format(self.id))
            return self.looking_for_pub, self.env.timeout(self['going_out_time']-self.now)

    @state
    def looking_for_pub(self):

        self.debug('Salimos, nuestra hora era {}'.format(self['going_out_time']))

        '''Look for a pub that accepts me and my friends'''
        if self['pub'] != None:
            return self.sober_in_pub

         

        self.debug('I am looking for a pub')
        group = list(self.get_neighboring_agents())

        r=random()
        if(self['age'] == 15):

            if (0.429>r):
                available_pubs = self.env.available_pubs()
                    

            elif ((0.429+0.337)>r):
                available_pubs = self.env.available_discos()

            else:
                available_pubs = self.env.available_street()

        elif(self['age'] == 20):

            if (0.509>r):
                available_pubs = self.env.available_pubs()

            elif (0.509+0.337>r):
                available_pubs = self.env.available_discos()

            else:
                available_pubs = self.env.available_street()

        else:

            if (0.629>r):
                available_pubs = self.env.available_pubs()
                    

            elif ((0.629+0.287)>r):
                available_pubs = self.env.available_discos()

            else:
                available_pubs = self.env.available_street()

        if (len(available_pubs)) == 0:
            available_pubs = self.env.available_pubs()
            self.info('No había discos y me voy mejor a un bar')

        if (len(available_pubs)) == 0:
            self.info('Tampoco hay bares, así que mejor nos vamos a casa')
            for friend in group:
                friend.set_state(self.at_home)
            return self.at_home


        for pub in available_pubs:
            
           
            self.debug('We\'re trying to get into {}: total: {}'.format(pub, len(group)))
            if self.env.enter(pub, self, *group):
                self.info('We\'re all {} getting in {}!'.format(len(group)+1, pub))
                capacity = self.env.return_occupancy(pub)
                self.info('{} now has {} people inside'.format(pub,capacity))
                return self.sober_in_pub
            else:
                self.info("We can\'t go inside {}".format(pub))

        if (self.env.return_type(available_pubs[0])=="disco") or  (self.env.return_type(available_pubs[0])=="street"):

            available_pubs = self.env.available_pubs()
            
            for pub in available_pubs:
            
                self.debug('We\'re trying to get into {}: total: {}'.format(pub, len(group)))
                if self.env.enter(pub, self, *group):
                    self.info('We\'re all {} getting in {}!'.format(len(group)+1, pub))
                    capacity = self.env.return_occupancy(pub)
                    self.info('{} now has {} people inside'.format(pub,capacity))
                    return self.sober_in_pub
                else:
                    self.info("We can\'t go inside {}".format(pub))

            self.info('No hay bares por donde salir. Nos vamos')
            for friend in group:
                friend.set_state(self.at_home)
            return self.at_home

        else:
            self.info('No hay bares por donde salir. Nos vamos')
            for friend in group:
                friend.set_state(self.at_home)
            return self.at_home

                
            # Si no puede entrar después de todas la iteraciones dar alternativa dependiendo
            # del caso. Buscan plan de otro tipo, en otro tipo de Venue. Si tampoco pueden, se van a casa
        


    @state
    def sober_in_pub(self):

        group = list(self.get_neighboring_agents())


        #Comprobar si hay razón para irse a casa

            #Amigo intoxicado o pelea

        for friend in group:
            if (friend['intoxicated']==True) or (friend['in_a_fight']==True):
                r = random()
                if r<0.7:
                    self.debug('Mi amigo {} se ha intoxicado o peleado. Me voy'.format(friend.id))
                    return self.at_home;
                    

                else:
                    self.debug('No ha tocado irse , amigo {} intoxicado/peleado'.format(friend.id))
            

            #Es hora de irse a casa
        if self.now == self['coming_back_time']:

            self.info('Es mi hora de irme a casa')
            return self.at_home
            

            # Quedan pocos amigos

        friends_remaining = len(list(self.get_neighboring_agents()))

        

        if ((self['group_size'] * 0.5) >= friends_remaining+1) or (friends_remaining==0):
            self.info('Me voy a casa porque habíamos salido {} y solo quedamos {}'.format(self['group_size'], friends_remaining+1))
            for friend in group:
                friend.set_state(self.at_home)
                
            return self.at_home

            #Check if a Patron has had a fight. It goes home

        if self['in_a_fight']==True:
            return self.at_home

        #Option of drinking a beverage
        self.drink()
    
        #Set prob_fight

        if self['age']==15 or self['age']==20:
            if self['gender']=="male":
                self['prob_fight']= 0.02 * self['pints']
            else:
                self['prob_fight']= 0.01 * self['pints']

        if self['age']==25:
            if self['gender']=="male":
                self['prob_fight']= 0.015 * self['pints']
            else:
                self['prob_fight']= 0.01 * self['pints']

        

        #Option of having a fight
        if self['in_a_fight']==False:
            r = random()
            if r<self['prob_fight']:
            
                self.fight()
        
       
        #Set prob_change_bar

        type = self.env.return_type(self['pub'])
      
        if(type=="disco"):
            self['prob_change_bar'] = 0

        else:
            self['prob_change_bar'] = 0.2


        #Option of changing pub if you are a leader

        if (self['is_leader'] and self['prob_change_bar']>random()) or (self['is_leader'] and not self.env.return_open(self['pub'])):
            self.change_bar()
            

        #Set prob_drink
        if self.now == (self['going_out_time']+4):
            if self['age']==15 or self['age']==20:
                if self['gender']=="male":
                    self['prob_drink']=0.4
                else:
                    self['prob_drink']=0.25

            if self['age']==25:
                if self['gender']=="male":
                    self['prob_drink']=0.3
                else:
                    self['prob_drink']=0.25
                


        if self.now == (self['going_out_time']+8):
            if self['gender']=="male":
                self['prob_drink']=0.25
            else:
                self['prob_drink']=0.2

        

        #Check if the Patron is drunk
        if self['pints'] > self['max_pints']:
            self['drunk'] = True
            self.info('I\'m so drunk.')
            return self.drunk_in_pub

        

        


    @state
    def drunk_in_pub(self):
        #Comrpobar si hhay razón para irse a casa
        #Option of having a fight
        #Set prob_change
        #Option of changing pub if you are a leader
        #Option of drinking a beverage
        #Check if the Patron is drunk
        
        #Set prob_fight
        #Set prob_drink
        
        group = list(self.get_neighboring_agents())


        #Comprobar si hay razón para irse a casa

            #Amigo intoxicado o pelea

        for friend in group:
            if (friend['intoxicated']==True) or (friend['in_a_fight']==True):
                r = random()
                if r<0.7:
                    self.debug('Mi amigo {} se ha intoxicado o peleado. Me voy'.format(friend.id))
                    return self.at_home;
                    

                else:
                    self.debug('No ha tocado irse , amigo {} intoxicado/peleado'.format(friend.id))
            

            #Es hora de irse a casa
        if self.now == self['coming_back_time']:

            self.info('Es mi hora de irme a casa')
            return self.at_home
            

            # Quedan pocos amigos

        friends_remaining = len(list(self.get_neighboring_agents()))

        

        if ((self['group_size'] * 0.5) >= friends_remaining+1) or (friends_remaining==0):
            self.info('Me voy a casa porque habíamos salido {} y solo quedamos {}'.format(self['group_size'], friends_remaining+1))
            for friend in group:
                friend.set_state(self.at_home)
                
            return self.at_home


            #Check if the Patron is intoxicated
        if self['pints'] > self['intoxication_drinkthreshold']:
            self.info('I got intoxicated')
            self['intoxicated'] = True
            return self.at_home


        #Check if a Patron has had a fight. It goes home

        if self['in_a_fight']==True:
            return self.at_home

        #Option of drinking a beverage
        self.drink()
    
        #Set prob_fight

        if self['age']==15 or self['age']==20:
            if self['gender']=="male":
                self['prob_fight']= 0.025 * self['pints']
            else:
                self['prob_fight']= 0.015 * self['pints']

        if self['age']==25:
            if self['gender']=="male":
                self['prob_fight']= 0.02 * self['pints']
            else:
                self['prob_fight']= 0.015 * self['pints']

        

        #Option of having a fight
        if self['in_a_fight']==False:
            r = random()
            if r<self['prob_fight']:
            
                self.fight()
        
       
        #Set prob_change_bar

        type = self.env.return_type(self['pub'])
      
        if(type=="disco"):
            self['prob_change_bar'] = 0

        else:
            self['prob_change_bar'] = 0.2


        #Option of changing pub if you are a leader

        if (self['is_leader'] and self['prob_change_bar']>random()) or (self['is_leader'] and not self.env.return_open(self['pub'])):
            self.change_bar()
            

        #Set prob_drink
        if self.now == (self['going_out_time']+4):
            if self['age']==15 or self['age']==20:
                if self['gender']=="male":
                    self['prob_drink']=0.4
                else:
                    self['prob_drink']=0.25

            if self['age']==25:
                if self['gender']=="male":
                    self['prob_drink']=0.3
                else:
                    self['prob_drink']=0.25
                


        if self.now == (self['going_out_time']+8):
            if self['gender']=="male":
                self['prob_drink']=0.25
            else:
                self['prob_drink']=0.2


    
    

    @state
    def at_home(self):
        '''The end'''
        self.debug('Life sucks. I\'m home!')
        if self['is_leader']==True:
            group = list(self.get_neighboring_agents())
            self.env.reelect_leader(*group)


        if (self['pub']!=None):
            occupancy = self.env.return_occupancy(self['pub'])
            self.env.set_occupancy(self['pub'], occupancy-1)
            self.debug('El venue tenia {} personas y ahora {}'.format(occupancy, self.env.return_occupancy(self['pub']) ))
            self['pub']=None
        else:
            self.debug('No tenía bar. Me han debido hacer kick out')

        self.die(remove=True)
    



    def change_bar(self):

            #Que cambien según itinerarios. Si num_changes=0, cambia dependiendo donde esté. 
            #Bar--> disco 
            #bar-->bar -->bar...
            #Street--> bar -->bar ...
            #Street--> disco
            #De las discoteca no sale nadie
            #Si se intenta cambiar a un sitio y no está disponible, se queda donde está (esto lo que hace es suponer que los agentes
            #se saben los horarios de los sitios)

        self.info('This member is going to change venue: {}'.format(self.id))

        current_pub = self['pub']
        type = self.env.return_type(self['pub'])

        group = list(self.get_neighboring_agents())
        r= random()


        #Pensar bien en las posibilidades y ver que hacen si no encuentran el sitio que buscan
        if(type== "disco"):

            available_pubs = self.env.available_discos()


        elif(type== "pub"):

            if self['num_of_changes']>4:
                available_pubs = self.env.available_pubs()

            else:
                r = random()

                if r<0.5 and self.now>=10:

                    available_pubs = self.env.available_discos()
                    
                else:
                    available_pubs = self.env.available_pubs()
                
        
        else:

            if (0.5>r):
                available_pubs = self.env.available_pubs()

            else:
                available_pubs = self.env.available_discos()

        if len(available_pubs) == 0:

            self.info("Nuestro plan se nos ha acabado")
            for friend in group:
                friend.set_state(self.at_home)
                self.debug('Me voy a casa en un bucle de estos:{}'.format(friend.id))
            
            self.set_state(self.at_home)
            return


        for pub in available_pubs:
            

            if self.env.return_name(pub) != current_pub:
                self.debug('We\'re trying to get into {}: total: {}'.format(pub, len(group)))
                if self.env.enter(pub, self, *group):
                    self.env.exit(current_pub,self, *group)
                    self.info('We\'re all {} changing to {}!'.format(len(group)+1, pub))
                    capacity = self.env.return_occupancy(pub)
                    self.info('{} now has {} people inside'.format(pub,capacity))

                    self['num_of_changes'] = self['num_of_changes']  + 1
                    for friend in group:
                        friend['num_of_changes'] = friend['num_of_changes']  + 1
                    
                    return
                    
                else:
                    self.debug("We can\'t go inside {}. There are {} people inside and is {}".format(pub, self.env.return_occupancy(pub),self.env.return_open(pub)))
        
        self.info('Al final no pudimos cambiar a ninguno y nos quedamos en este')

          ##Si no puede entrar después de todas la iteraciones dar alternativa dependiendo
          #del caso. Si no pueden por precio (se quedan donde están), o si no pueden por horario (se quedan donde están)
                #O no caben: , vuelven a otro del tipo anterior donde estaban

        

    def fight(self):
        fighters = list(self.get_agents(pub=self['pub']))
        shuffle(fighters)
        #fighters.remove('xyz');


        if (len(fighters)==1):
            self.info('No hay nadie con quien pelear')
            return

        for fighter in fighters:
            if fighter.id!=self.id:
                election = fighter
        
        for fighter in fighters:
            if (fighter['prob_fight']>election['prob_fight']) and (fighter.id!=self.id) and (not fighter['in_a_fight']):
                election = fighter

        self.info('Me peleo con {}'.format(election.id))

        self['in_a_fight']=True
        election['in_a_fight']=True
        self['num_of_fights']+=1
        election['num_of_fights']+=1

    
    def drink(self):
        price = self.env.return_price(self['pub'])
        
        #Políticas no vender a menores
            
        if(self['prob_drink']>random() and price<self['money']): #and self['age']<18S:
            self['pints'] = self['pints'] + 1
            self['money'] = self['money'] -  price
            self.debug('Cheers to that')
            
            self.debug('The price is {} € at {}'.format(price,self['pub']))

    def kick_out(self):

        occupancy = self.env.return_occupancy(self['pub'])
        self.env.set_occupancy(self['pub'], occupancy-1)
        self.info('El venue tenia {} personas y ahora {}'.format(occupancy, self.env.return_occupancy(self['pub']) ))
        self['pub']=None
        

        #self.set_state(self.at_home)

    def befriend(self, other_agent):
        '''
        Try to become friends with another agent. The chances of
        success depend on both agents' openness.
        '''
       
        self.env.add_edge(self, other_agent)
        self.debug('Made some friend, agent {}'.format(other_agent.id))
        return True
        

    def try_friends(self, others):
        ''' Look for random agents around me and try to befriend them'''
        n=1
        befriended = False
        r = random()
        if r<0.1:
            k = randint(3,5)
        elif r<0.411:
            k = randint(6,10)
        else:
            k=randint(10,15)

        shuffle(others)
        for friend in islice(others, k):  # random.choice >= 3.7
            if friend == self:
                continue
            if friend.befriend(self):
                self.befriend(friend)
                #self.info('Hooray! new friend: {}'.format(friend.id))
                n = n+1
                befriended = True
            else:
                self.info('{} does not want to be friends'.format(friend.id))

        self['in_a_group'] = True
        
        neighbors_leader = list(self.get_neighboring_agents())

        #print(*neighbors_leader)
        
        for people in neighbors_leader:
            people['in_a_group'] = True
            
            for i in neighbors_leader:
                if (people!=i):
                    people.befriend(i)

        self.info('Now we are a group: ')
        for people in neighbors_leader:
            self.info('{}'.format(people.id))
        return befriended

# %%
class Police(FSM):
    
    level = logging.INFO

    @default_state
    @state
    def patrol(self):


        '''Abre o cierra los bares'''
        pubs = self.env.get_venues() 

        self.debug('CONTADOR:')
        self.debug('Ya hay {} Patrons en su casa'.format(len(list(self.get_agents(state_id=Patron.at_home.id)))))

        for pub in pubs:

            if self.now == self.env.return_opening_time(pub):
                self.env.set_open(pub)
                self.info('El {} ha abierto'.format(pub))

            

            self.debug('{} tiene dentro {} personas'.format(self.env.return_name(pub),self.env.return_occupancy(pub)))
            if self.now == self.env.return_closing_time(pub):
                self.env.set_close(pub)
                self.info('El {} ha cerrado con {} personas dentro'.format(pub, self.env.return_occupancy(pub)))
                #Echa a toda la gente de dentro, mirar qué hacen los agentes cuando les echan


        '''Echará a los que están intoxicados en un local'''
        intoxicates = list(self.get_agents(intoxicated=True))
        for intoxicate in intoxicates:
            self.info('Kicking out the intoxicated agents: {}'.format(intoxicate.id))
            intoxicate.kick_out()


        '''Echará a los que se han peleado en un local'''
        agents = list(self.get_agents(in_a_fight=True))
        for agent in agents:
            if (self.env.return_type(agent['pub'])=="disco") or (self.env.return_type(agent['pub'])=="pub"):
                self.info('Kicking out the fight agents: {}'.format(agent.id))
                agent.kick_out()
                #Tenemos en cuenta que un agente que se pelea se va a casa. Sus amigos ya verán si se van. SI es así, tengo que
                #poner en sober y frunk que se vayam los peleados

            


        '''Pequeña funcionalidad que viene bien poner aquí'''
       
        for agent in agents:
            agent['in_a_fight']==False


        '''Politicas a probar'''

        '''
        #A partir de las 2am no se puede vender alcohol, en los pubs y discos
        if self.now == 18:
            self.info('Política aplicada: no se vende ya más alcohol. Son las 2am')
            for pub in pubs:
                if (self.env.return_type(pub)=="pub" or self.env.return_type(pub)=="disco"):
                    self.env.set_price(pub,200)
        '''
        

        #No vender alcohol a menores en todo el modelo

                #Función drink

        #Precios minimos para el alcohol. Subimos los precios un 20%
        '''
        percentage = 0.2
        if self.now == 1:
            self.info('Subida de los precios en un {} %'.format(percentage*100))
            for pub in pubs:
                
                self.env.set_price(pub,self.env.return_price(pub)*(1+percentage))
        '''
        
        '''
        #No se puede hacer public drinking
        agents = list(self.get_agents(is_leader=True))
        for agent in agents:
            if self.env.return_type(agent['pub'])=="street":
                self.info('Hay policia en la zona de botellón. Nos vamos a otro lado')
                agent.change_bar()

        '''


        #A partir de las 2:30am en bares y 5am en discos ya solo se puede salir 

        if self.now == 20: 
            
            for pub in pubs:
                if self.env.return_type(pub)=="pub":
                    self.env.set_entry(pub,3000)

        if self.now == 30:
            for pub in pubs:
                if self.env.return_type(pub)=="disco":
                    self.env.set_entry(pub,3000)


        #Limitar el horario de los venues para que cierren más pronto
        #Todas las discos cierran a las 5am y los bares a las 2am:
        '''
        if self.now == 1:
            self.info('Limitación de horarios')
        for pub in pubs:
            if (self.env.return_type(pub)=="disco"):
                self.env.set_closing_time(pub,30) 


            elif (self.env.return_type(pub)=="pub"):
                self.env.set_closing_time(pub,18) 

        '''

# %%
simulation.run_from_config('pubcrawl.yml',
                               
                               dump=None,
                               )
# Out:
# INFO:soil:Using config(s): Malasana
# INFO:soil:Dumping results to soil_output/Malasana : False
# INFO:soil:Starting simulation Malasana at 18:29:08.
# INFO:soil:Starting Simulation Malasana trial 0 at 18:29:47.
# INFO:soil:Environment stats:
# agents:
#   model_count:
#     Patron: 1500
#   state_count:
#     setting_parameters: 1500
# network:
#   n_edges: 0
#   n_nodes: 1500
# params:
#   SEED: NoneMalasana_trial_0
#   pubs:
#     'The awesome disco #0':
#       capacity: 1017.3993832699213
#       closing_time: 36
#       entry: 18
#       name: 'The awesome disco #0'
#       occupancy: 0
#       open: false
#       opening_time: 10
#       price: 9
#       type: disco
#     'The awesome pub #0':
#       capacity: 106.63346730070982
#       closing_time: 20
#       entry: 0
#       name: 'The awesome pub #0'
#       occupancy: 0
#       open: false
#       opening_time: 1
#       price: 7
#       type: pub
#     'The awesome pub #1':
#       capacity: 100.67283446707194
#       closing_time: 24
#       entry: 0
#       name: 'The awesome pub #1'
#       occupancy: 0
#       open: false
#       opening_time: 1
#       price: 7
#       type: pub
#     'The awesome pub #2':
#       capacity: 109.4224481976463
#       closing_time: 23
#       entry: 0
#       name: 'The awesome pub #2'
#       occupancy: 0
#       open: false
#       opening_time: 1
#       price: 5
#       type: pub
#     'The awesome pub #3':
#       capacity: 110.67434293979768
#       closing_time: 23
#       entry: 0
#       name: 'The awesome pub #3'
#       occupancy: 0
#       open: false
#       opening_time: 1
#       price: 7
#       type: pub
#     'The awesome pub #4':
#       capacity: 48.55363565336951
#       closing_time: 21
#       entry: 0
#       name: 'The awesome pub #4'
#       occupancy: 0
#       open: false
#       opening_time: 1
#       price: 7
#       type: pub
#     'The awesome pub #5':
#       capacity: 102.32646812256512
#       closing_time: 20
#       entry: 0
#       name: 'The awesome pub #5'
#       occupancy: 0
#       open: false
#       opening_time: 1
#       price: 7
#       type: pub
#     'The awesome pub #6':
#       capacity: 93.23602020424855
#       closing_time: 20
#       entry: 0
#       name: 'The awesome pub #6'
#       occupancy: 0
#       open: false
#       opening_time: 1
#       price: 5
#       type: pub
#     'The awesome pub #7':
#       capacity: 102.75683747923262
#       closing_time: 22
#       entry: 0
#       name: 'The awesome pub #7'
#       occupancy: 0
#       open: false
#       opening_time: 1
#       price: 7
#       type: pub
#     'The awesome pub #8':
#       capacity: 112.5339121267704
#       closing_time: 23
#       entry: 0
#       name: 'The awesome pub #8'
#       occupancy: 0
#       open: false
#       opening_time: 1
#       price: 6
#       type: pub
#     'The awesome pub #9':
#       capacity: 118.30206982465643
#       closing_time: 23
#       entry: 0
#       name: 'The awesome pub #9'
#       occupancy: 0
#       open: false
#       opening_time: 1
#       price: 7
#       type: pub
#     'The awesome street #0':
#       capacity: 10000
#       closing_time: 39
#       entry: 0
#       name: 'The awesome street #0'
#       occupancy: 0
#       open: false
#       opening_time: 1
#       price: 5
#       type: street
#
# INFO:Malasana_trial_0.Police:	Police[Police]@    1:	El The awesome pub #8 ha abierto
# INFO:Malasana_trial_0.Police:	Police[Police]@    1:	El The awesome pub #6 ha abierto
# INFO:Malasana_trial_0.Police:	Police[Police]@    1:	El The awesome pub #3 ha abierto
# INFO:Malasana_trial_0.Police:	Police[Police]@    1:	El The awesome pub #2 ha abierto
# INFO:Malasana_trial_0.Police:	Police[Police]@    1:	El The awesome pub #1 ha abierto
# INFO:Malasana_trial_0.Police:	Police[Police]@    1:	El The awesome street #0 ha abierto
# INFO:Malasana_trial_0.Police:	Police[Police]@    1:	El The awesome pub #0 ha abierto
# INFO:Malasana_trial_0.Police:	Police[Police]@    1:	El The awesome pub #4 ha abierto
# INFO:Malasana_trial_0.Police:	Police[Police]@    1:	El The awesome pub #9 ha abierto
# INFO:Malasana_trial_0.Police:	Police[Police]@    1:	El The awesome pub #5 ha abierto
# INFO:Malasana_trial_0.Police:	Police[Police]@    1:	El The awesome pub #7 ha abierto
# INFO:Malasana_trial_0.0:	Patron[0] @    1:	I am looking for friends
# INFO:Malasana_trial_0.0:	Patron[0] @    1:	Now we are a group:
# INFO:Malasana_trial_0.0:	Patron[0] @    1:	289
# INFO:Malasana_trial_0.0:	Patron[0] @    1:	931
# INFO:Malasana_trial_0.0:	Patron[0] @    1:	310
# INFO:Malasana_trial_0.0:	Patron[0] @    1:	1162
# INFO:Malasana_trial_0.0:	Patron[0] @    1:	460
# INFO:Malasana_trial_0.0:	Patron[0] @    1:	112
# INFO:Malasana_trial_0.0:	Patron[0] @    1:	1106
# INFO:Malasana_trial_0.0:	Patron[0] @    1:	1243
# INFO:Malasana_trial_0.0:	Patron[0] @    1:	152
# INFO:Malasana_trial_0.0:	Patron[0] @    1:	27
# INFO:Malasana_trial_0.0:	Patron[0] @    1:	93
# INFO:Malasana_trial_0.0:	Patron[0] @    1:	638
# INFO:Malasana_trial_0.0:	Patron[0] @    1:	485
# INFO:Malasana_trial_0.1:	Patron[1] @    1:	I am looking for friends
# INFO:Malasana_trial_0.1:	Patron[1] @    1:	Now we are a group:
# INFO:Malasana_trial_0.1:	Patron[1] @    1:	424
# INFO:Malasana_trial_0.1:	Patron[1] @    1:	297
# INFO:Malasana_trial_0.1:	Patron[1] @    1:	759
# INFO:Malasana_trial_0.1:	Patron[1] @    1:	908
# INFO:Malasana_trial_0.1:	Patron[1] @    1:	498
# INFO:Malasana_trial_0.1:	Patron[1] @    1:	1039
# INFO:Malasana_trial_0.1:	Patron[1] @    1:	658
# INFO:Malasana_trial_0.1:	Patron[1] @    1:	851
# INFO:Malasana_trial_0.1:	Patron[1] @    1:	1492
# INFO:Malasana_trial_0.1:	Patron[1] @    1:	85
# INFO:Malasana_trial_0.1:	Patron[1] @    1:	87
# INFO:Malasana_trial_0.1:	Patron[1] @    1:	1300
# INFO:Malasana_trial_0.1:	Patron[1] @    1:	380
# INFO:Malasana_trial_0.1:	Patron[1] @    1:	797
# INFO:Malasana_trial_0.1:	Patron[1] @    1:	382
# INFO:Malasana_trial_0.2:	Patron[2] @    1:	I am looking for friends
# INFO:Malasana_trial_0.2:	Patron[2] @    1:	Now we are a group:
# INFO:Malasana_trial_0.2:	Patron[2] @    1:	728
# INFO:Malasana_trial_0.2:	Patron[2] @    1:	765
# INFO:Malasana_trial_0.2:	Patron[2] @    1:	69
# INFO:Malasana_trial_0.2:	Patron[2] @    1:	1373
# INFO:Malasana_trial_0.2:	Patron[2] @    1:	136
# INFO:Malasana_trial_0.2:	Patron[2] @    1:	794
# INFO:Malasana_trial_0.2:	Patron[2] @    1:	1261
# INFO:Malasana_trial_0.2:	Patron[2] @    1:	1475
# INFO:Malasana_trial_0.2:	Patron[2] @    1:	1071
# INFO:Malasana_trial_0.3:	Patron[3] @    1:	I am looking for friends
# INFO:Malasana_trial_0.3:	Patron[3] @    1:	Now we are a group:
# INFO:Malasana_trial_0.3:	Patron[3] @    1:	1344
# INFO:Malasana_trial_0.3:	Patron[3] @    1:	129
# INFO:Malasana_trial_0.3:	Patron[3] @    1:	994
# INFO:Malasana_trial_0.3:	Patron[3] @    1:	356
# INFO:Malasana_trial_0.3:	Patron[3] @    1:	423
# INFO:Malasana_trial_0.3:	Patron[3] @    1:	743
# INFO:Malasana_trial_0.3:	Patron[3] @    1:	588
# INFO:Malasana_trial_0.3:	Patron[3] @    1:	753
# INFO:Malasana_trial_0.3:	Patron[3] @    1:	1267
# INFO:Malasana_trial_0.3:	Patron[3] @    1:	119
# INFO:Malasana_trial_0.3:	Patron[3] @    1:	1220
# INFO:Malasana_trial_0.3:	Patron[3] @    1:	640
# INFO:Malasana_trial_0.3:	Patron[3] @    1:	635
# INFO:Malasana_trial_0.3:	Patron[3] @    1:	604
# INFO:Malasana_trial_0.3:	Patron[3] @    1:	1239
# INFO:Malasana_trial_0.4:	Patron[4] @    1:	I am looking for friends
# INFO:Malasana_trial_0.4:	Patron[4] @    1:	Now we are a group:
# INFO:Malasana_trial_0.4:	Patron[4] @    1:	864
# INFO:Malasana_trial_0.4:	Patron[4] @    1:	97
# INFO:Malasana_trial_0.4:	Patron[4] @    1:	578
# INFO:Malasana_trial_0.4:	Patron[4] @    1:	739
# INFO:Malasana_trial_0.4:	Patron[4] @    1:	772
# INFO:Malasana_trial_0.4:	Patron[4] @    1:	1031
# INFO:Malasana_trial_0.4:	Patron[4] @    1:	1464
# INFO:Malasana_trial_0.4:	Patron[4] @    1:	1289
# INFO:Malasana_trial_0.4:	Patron[4] @    1:	474
# INFO:Malasana_trial_0.4:	Patron[4] @    1:	860
# INFO:Malasana_trial_0.4:	Patron[4] @    1:	410
# INFO:Malasana_trial_0.5:	Patron[5] @    1:	I am looking for friends
# INFO:Malasana_trial_0.5:	Patron[5] @    1:	Now we are a group:
# INFO:Malasana_trial_0.5:	Patron[5] @    1:	625
# INFO:Malasana_trial_0.5:	Patron[5] @    1:	1342
# INFO:Malasana_trial_0.5:	Patron[5] @    1:	247
# INFO:Malasana_trial_0.5:	Patron[5] @    1:	225
# INFO:Malasana_trial_0.5:	Patron[5] @    1:	233
# INFO:Malasana_trial_0.5:	Patron[5] @    1:	682
# INFO:Malasana_trial_0.5:	Patron[5] @    1:	619
# INFO:Malasana_trial_0.5:	Patron[5] @    1:	44
# INFO:Malasana_trial_0.5:	Patron[5] @    1:	1098
# INFO:Malasana_trial_0.5:	Patron[5] @    1:	1326
# INFO:Malasana_trial_0.6:	Patron[6] @    1:	I am looking for friends
# INFO:Malasana_trial_0.6:	Patron[6] @    1:	Now we are a group:
# INFO:Malasana_trial_0.6:	Patron[6] @    1:	560
# INFO:Malasana_trial_0.6:	Patron[6] @    1:	530
# INFO:Malasana_trial_0.6:	Patron[6] @    1:	1091
# INFO:Malasana_trial_0.6:	Patron[6] @    1:	108
# INFO:Malasana_trial_0.6:	Patron[6] @    1:	1402
# INFO:Malasana_trial_0.6:	Patron[6] @    1:	363
# INFO:Malasana_trial_0.6:	Patron[6] @    1:	1420
# INFO:Malasana_trial_0.6:	Patron[6] @    1:	127
# INFO:Malasana_trial_0.7:	Patron[7] @    1:	I am looking for friends
# INFO:Malasana_trial_0.7:	Patron[7] @    1:	Now we are a group:
# INFO:Malasana_trial_0.7:	Patron[7] @    1:	128
# INFO:Malasana_trial_0.7:	Patron[7] @    1:	420
# INFO:Malasana_trial_0.7:	Patron[7] @    1:	790
# INFO:Malasana_trial_0.7:	Patron[7] @    1:	72
# INFO:Malasana_trial_0.7:	Patron[7] @    1:	809
# INFO:Malasana_trial_0.7:	Patron[7] @    1:	1260
# INFO:Malasana_trial_0.7:	Patron[7] @    1:	717
# INFO:Malasana_trial_0.7:	Patron[7] @    1:	200
# INFO:Malasana_trial_0.7:	Patron[7] @    1:	1270
# INFO:Malasana_trial_0.7:	Patron[7] @    1:	727
# INFO:Malasana_trial_0.7:	Patron[7] @    1:	1336
# INFO:Malasana_trial_0.7:	Patron[7] @    1:	857
# INFO:Malasana_trial_0.8:	Patron[8] @    1:	I am looking for friends
# INFO:Malasana_trial_0.8:	Patron[8] @    1:	Now we are a group:
# INFO:Malasana_trial_0.8:	Patron[8] @    1:	1265
# INFO:Malasana_trial_0.8:	Patron[8] @    1:	1474
# INFO:Malasana_trial_0.8:	Patron[8] @    1:	1051
# INFO:Malasana_trial_0.8:	Patron[8] @    1:	748
# INFO:Malasana_trial_0.8:	Patron[8] @    1:	898
# INFO:Malasana_trial_0.8:	Patron[8] @    1:	783
# INFO:Malasana_trial_0.9:	Patron[9] @    1:	I am looking for friends
# INFO:Malasana_trial_0.9:	Patron[9] @    1:	Now we are a group:
# INFO:Malasana_trial_0.9:	Patron[9] @    1:	480
# INFO:Malasana_trial_0.9:	Patron[9] @    1:	1163
# INFO:Malasana_trial_0.9:	Patron[9] @    1:	805
# INFO:Malasana_trial_0.9:	Patron[9] @    1:	934
# INFO:Malasana_trial_0.9:	Patron[9] @    1:	811
# INFO:Malasana_trial_0.9:	Patron[9] @    1:	1355
# INFO:Malasana_trial_0.9:	Patron[9] @    1:	719
# INFO:Malasana_trial_0.9:	Patron[9] @    1:	1456
# INFO:Malasana_trial_0.9:	Patron[9] @    1:	337
# INFO:Malasana_trial_0.9:	Patron[9] @    1:	99
# INFO:Malasana_trial_0.9:	Patron[9] @    1:	852
# INFO:Malasana_trial_0.9:	Patron[9] @    1:	374
# INFO:Malasana_trial_0.9:	Patron[9] @    1:	265
# INFO:Malasana_trial_0.9:	Patron[9] @    1:	378
# INFO:Malasana_trial_0.9:	Patron[9] @    1:	254
# INFO:Malasana_trial_0.10:	Patron[10]@    1:	I am looking for friends
# INFO:Malasana_trial_0.10:	Patron[10]@    1:	Now we are a group:
# INFO:Malasana_trial_0.10:	Patron[10]@    1:	520
# INFO:Malasana_trial_0.10:	Patron[10]@    1:	1161
# INFO:Malasana_trial_0.10:	Patron[10]@    1:	270
# INFO:Malasana_trial_0.11:	Patron[11]@    1:	I am looking for friends
# INFO:Malasana_trial_0.11:	Patron[11]@    1:	Now we are a group:
# INFO:Malasana_trial_0.11:	Patron[11]@    1:	107
# INFO:Malasana_trial_0.11:	Patron[11]@    1:	835
# INFO:Malasana_trial_0.11:	Patron[11]@    1:	564
# INFO:Malasana_trial_0.11:	Patron[11]@    1:	919
# INFO:Malasana_trial_0.11:	Patron[11]@    1:	57
# INFO:Malasana_trial_0.11:	Patron[11]@    1:	394
# INFO:Malasana_trial_0.11:	Patron[11]@    1:	355
# INFO:Malasana_trial_0.11:	Patron[11]@    1:	396
# INFO:Malasana_trial_0.11:	Patron[11]@    1:	1118
# INFO:Malasana_trial_0.12:	Patron[12]@    1:	I am looking for friends
# INFO:Malasana_trial_0.12:	Patron[12]@    1:	Now we are a group:
# INFO:Malasana_trial_0.12:	Patron[12]@    1:	161
# INFO:Malasana_trial_0.12:	Patron[12]@    1:	427
# INFO:Malasana_trial_0.12:	Patron[12]@    1:	627
# INFO:Malasana_trial_0.12:	Patron[12]@    1:	121
# INFO:Malasana_trial_0.12:	Patron[12]@    1:	47
# INFO:Malasana_trial_0.12:	Patron[12]@    1:	747
# INFO:Malasana_trial_0.12:	Patron[12]@    1:	767
# INFO:Malasana_trial_0.12:	Patron[12]@    1:	125
# INFO:Malasana_trial_0.12:	Patron[12]@    1:	911
# INFO:Malasana_trial_0.13:	Patron[13]@    1:	I am looking for friends
# INFO:Malasana_trial_0.13:	Patron[13]@    1:	Now we are a group:
# INFO:Malasana_trial_0.13:	Patron[13]@    1:	1328
# INFO:Malasana_trial_0.13:	Patron[13]@    1:	605
# INFO:Malasana_trial_0.13:	Patron[13]@    1:	1030
# INFO:Malasana_trial_0.14:	Patron[14]@    1:	I am looking for friends
# INFO:Malasana_trial_0.14:	Patron[14]@    1:	Now we are a group:
# INFO:Malasana_trial_0.14:	Patron[14]@    1:	1235
# INFO:Malasana_trial_0.14:	Patron[14]@    1:	1001
# INFO:Malasana_trial_0.14:	Patron[14]@    1:	395
# INFO:Malasana_trial_0.14:	Patron[14]@    1:	974
# INFO:Malasana_trial_0.14:	Patron[14]@    1:	1167
# INFO:Malasana_trial_0.14:	Patron[14]@    1:	1137
# INFO:Malasana_trial_0.14:	Patron[14]@    1:	1458
# INFO:Malasana_trial_0.14:	Patron[14]@    1:	403
# INFO:Malasana_trial_0.14:	Patron[14]@    1:	1268
# INFO:Malasana_trial_0.14:	Patron[14]@    1:	1333
# INFO:Malasana_trial_0.14:	Patron[14]@    1:	1401
# INFO:Malasana_trial_0.14:	Patron[14]@    1:	249
# INFO:Malasana_trial_0.14:	Patron[14]@    1:	666
# INFO:Malasana_trial_0.14:	Patron[14]@    1:	1371
# INFO:Malasana_trial_0.15:	Patron[15]@    1:	I am looking for friends
# INFO:Malasana_trial_0.15:	Patron[15]@    1:	Now we are a group:
# INFO:Malasana_trial_0.15:	Patron[15]@    1:	850
# INFO:Malasana_trial_0.15:	Patron[15]@    1:	259
# INFO:Malasana_trial_0.15:	Patron[15]@    1:	565
# INFO:Malasana_trial_0.15:	Patron[15]@    1:	278
# INFO:Malasana_trial_0.15:	Patron[15]@    1:	537
# INFO:Malasana_trial_0.15:	Patron[15]@    1:	1266
# INFO:Malasana_trial_0.15:	Patron[15]@    1:	711
# INFO:Malasana_trial_0.15:	Patron[15]@    1:	589
# INFO:Malasana_trial_0.15:	Patron[15]@    1:	878
# INFO:Malasana_trial_0.15:	Patron[15]@    1:	117
# INFO:Malasana_trial_0.16:	Patron[16]@    1:	I am looking for friends
# INFO:Malasana_trial_0.16:	Patron[16]@    1:	Now we are a group:
# INFO:Malasana_trial_0.16:	Patron[16]@    1:	240
# INFO:Malasana_trial_0.16:	Patron[16]@    1:	1233
# INFO:Malasana_trial_0.16:	Patron[16]@    1:	50
# INFO:Malasana_trial_0.16:	Patron[16]@    1:	998
# INFO:Malasana_trial_0.16:	Patron[16]@    1:	40
# INFO:Malasana_trial_0.16:	Patron[16]@    1:	1468
# INFO:Malasana_trial_0.16:	Patron[16]@    1:	1084
# INFO:Malasana_trial_0.16:	Patron[16]@    1:	226
# INFO:Malasana_trial_0.16:	Patron[16]@    1:	366
# INFO:Malasana_trial_0.17:	Patron[17]@    1:	I am looking for friends
# INFO:Malasana_trial_0.17:	Patron[17]@    1:	Now we are a group:
# INFO:Malasana_trial_0.17:	Patron[17]@    1:	1408
# INFO:Malasana_trial_0.17:	Patron[17]@    1:	807
# INFO:Malasana_trial_0.17:	Patron[17]@    1:	969
# INFO:Malasana_trial_0.17:	Patron[17]@    1:	906
# INFO:Malasana_trial_0.17:	Patron[17]@    1:	1452
# INFO:Malasana_trial_0.17:	Patron[17]@    1:	494
# INFO:Malasana_trial_0.17:	Patron[17]@    1:	880
# INFO:Malasana_trial_0.17:	Patron[17]@    1:	1198
# INFO:Malasana_trial_0.17:	Patron[17]@    1:	472
# INFO:Malasana_trial_0.17:	Patron[17]@    1:	59
# INFO:Malasana_trial_0.17:	Patron[17]@    1:	1034
# INFO:Malasana_trial_0.17:	Patron[17]@    1:	926
# INFO:Malasana_trial_0.17:	Patron[17]@    1:	1023
# INFO:Malasana_trial_0.18:	Patron[18]@    1:	I am looking for friends
# INFO:Malasana_trial_0.18:	Patron[18]@    1:	Now we are a group:
# INFO:Malasana_trial_0.18:	Patron[18]@    1:	610
# INFO:Malasana_trial_0.18:	Patron[18]@    1:	645
# INFO:Malasana_trial_0.18:	Patron[18]@    1:	1446
# INFO:Malasana_trial_0.18:	Patron[18]@    1:	937
# INFO:Malasana_trial_0.18:	Patron[18]@    1:	203
# INFO:Malasana_trial_0.18:	Patron[18]@    1:	28
# INFO:Malasana_trial_0.18:	Patron[18]@    1:	978
# INFO:Malasana_trial_0.18:	Patron[18]@    1:	502
# INFO:Malasana_trial_0.18:	Patron[18]@    1:	600
# INFO:Malasana_trial_0.18:	Patron[18]@    1:	92
# INFO:Malasana_trial_0.18:	Patron[18]@    1:	190
# INFO:Malasana_trial_0.18:	Patron[18]@    1:	389
# INFO:Malasana_trial_0.19:	Patron[19]@    1:	I am looking for friends
# INFO:Malasana_trial_0.19:	Patron[19]@    1:	Now we are a group:
# INFO:Malasana_trial_0.19:	Patron[19]@    1:	997
# INFO:Malasana_trial_0.19:	Patron[19]@    1:	198
# INFO:Malasana_trial_0.19:	Patron[19]@    1:	905
# INFO:Malasana_trial_0.19:	Patron[19]@    1:	664
# INFO:Malasana_trial_0.19:	Patron[19]@    1:	1081
# INFO:Malasana_trial_0.19:	Patron[19]@    1:	1306
# INFO:Malasana_trial_0.19:	Patron[19]@    1:	1471
# INFO:Malasana_trial_0.19:	Patron[19]@    1:	1164
# INFO:Malasana_trial_0.19:	Patron[19]@    1:	1290
# INFO:Malasana_trial_0.19:	Patron[19]@    1:	1197
# INFO:Malasana_trial_0.20:	Patron[20]@    1:	I am looking for friends
# INFO:Malasana_trial_0.20:	Patron[20]@    1:	Now we are a group:
# INFO:Malasana_trial_0.20:	Patron[20]@    1:	383
# INFO:Malasana_trial_0.20:	Patron[20]@    1:	856
# INFO:Malasana_trial_0.20:	Patron[20]@    1:	1490
# INFO:Malasana_trial_0.20:	Patron[20]@    1:	1347
# INFO:Malasana_trial_0.20:	Patron[20]@    1:	840
# INFO:Malasana_trial_0.20:	Patron[20]@    1:	217
# INFO:Malasana_trial_0.20:	Patron[20]@    1:	26
# INFO:Malasana_trial_0.20:	Patron[20]@    1:	1339
# INFO:Malasana_trial_0.20:	Patron[20]@    1:	1405
# INFO:Malasana_trial_0.20:	Patron[20]@    1:	1037
# INFO:Malasana_trial_0.21:	Patron[21]@    1:	I am looking for friends
# INFO:Malasana_trial_0.21:	Patron[21]@    1:	Now we are a group:
# INFO:Malasana_trial_0.21:	Patron[21]@    1:	770
# INFO:Malasana_trial_0.21:	Patron[21]@    1:	787
# INFO:Malasana_trial_0.21:	Patron[21]@    1:	1146
# INFO:Malasana_trial_0.21:	Patron[21]@    1:	43
# INFO:Malasana_trial_0.21:	Patron[21]@    1:	1212
# INFO:Malasana_trial_0.21:	Patron[21]@    1:	110
# INFO:Malasana_trial_0.21:	Patron[21]@    1:	143
# INFO:Malasana_trial_0.22:	Patron[22]@    1:	I am looking for friends
# INFO:Malasana_trial_0.22:	Patron[22]@    1:	Now we are a group:
# INFO:Malasana_trial_0.22:	Patron[22]@    1:	384
# INFO:Malasana_trial_0.22:	Patron[22]@    1:	338
# INFO:Malasana_trial_0.22:	Patron[22]@    1:	1301
# INFO:Malasana_trial_0.22:	Patron[22]@    1:	1470
# INFO:Malasana_trial_0.22:	Patron[22]@    1:	695
# INFO:Malasana_trial_0.23:	Patron[23]@    1:	I am looking for friends
# INFO:Malasana_trial_0.23:	Patron[23]@    1:	Now we are a group:
# INFO:Malasana_trial_0.23:	Patron[23]@    1:	116
# INFO:Malasana_trial_0.23:	Patron[23]@    1:	216
# INFO:Malasana_trial_0.23:	Patron[23]@    1:	281
# INFO:Malasana_trial_0.23:	Patron[23]@    1:	1388
# INFO:Malasana_trial_0.23:	Patron[23]@    1:	381
# INFO:Malasana_trial_0.23:	Patron[23]@    1:	750
# INFO:Malasana_trial_0.23:	Patron[23]@    1:	431
# INFO:Malasana_trial_0.24:	Patron[24]@    1:	I am looking for friends
# INFO:Malasana_trial_0.24:	Patron[24]@    1:	Now we are a group:
# INFO:Malasana_trial_0.24:	Patron[24]@    1:	1024
# INFO:Malasana_trial_0.24:	Patron[24]@    1:	1451
# INFO:Malasana_trial_0.24:	Patron[24]@    1:	324
# INFO:Malasana_trial_0.24:	Patron[24]@    1:	683
# INFO:Malasana_trial_0.24:	Patron[24]@    1:	524
# INFO:Malasana_trial_0.24:	Patron[24]@    1:	685
# INFO:Malasana_trial_0.24:	Patron[24]@    1:	495
# INFO:Malasana_trial_0.24:	Patron[24]@    1:	1264
# INFO:Malasana_trial_0.24:	Patron[24]@    1:	721
# INFO:Malasana_trial_0.24:	Patron[24]@    1:	596
# INFO:Malasana_trial_0.24:	Patron[24]@    1:	1013
# INFO:Malasana_trial_0.24:	Patron[24]@    1:	446
# INFO:Malasana_trial_0.24:	Patron[24]@    1:	440
# INFO:Malasana_trial_0.24:	Patron[24]@    1:	698
# INFO:Malasana_trial_0.24:	Patron[24]@    1:	1304
# INFO:Malasana_trial_0.25:	Patron[25]@    1:	I am looking for friends
# INFO:Malasana_trial_0.25:	Patron[25]@    1:	Now we are a group:
# INFO:Malasana_trial_0.25:	Patron[25]@    1:	592
# INFO:Malasana_trial_0.25:	Patron[25]@    1:	1360
# INFO:Malasana_trial_0.25:	Patron[25]@    1:	306
# INFO:Malasana_trial_0.25:	Patron[25]@    1:	932
# INFO:Malasana_trial_0.25:	Patron[25]@    1:	1254
# INFO:Malasana_trial_0.25:	Patron[25]@    1:	601
# INFO:Malasana_trial_0.25:	Patron[25]@    1:	184
# INFO:Malasana_trial_0.25:	Patron[25]@    1:	508
# INFO:Malasana_trial_0.25:	Patron[25]@    1:	364
# INFO:Malasana_trial_0.25:	Patron[25]@    1:	1424
# INFO:Malasana_trial_0.25:	Patron[25]@    1:	846
# INFO:Malasana_trial_0.29:	Patron[29]@    1:	I am looking for friends
# INFO:Malasana_trial_0.29:	Patron[29]@    1:	Now we are a group:
# INFO:Malasana_trial_0.29:	Patron[29]@    1:	921
# INFO:Malasana_trial_0.29:	Patron[29]@    1:	467
# INFO:Malasana_trial_0.29:	Patron[29]@    1:	292
# INFO:Malasana_trial_0.30:	Patron[30]@    1:	I am looking for friends
# INFO:Malasana_trial_0.30:	Patron[30]@    1:	Now we are a group:
# INFO:Malasana_trial_0.30:	Patron[30]@    1:	35
# INFO:Malasana_trial_0.30:	Patron[30]@    1:	1204
# INFO:Malasana_trial_0.30:	Patron[30]@    1:	662
# INFO:Malasana_trial_0.30:	Patron[30]@    1:	375
# INFO:Malasana_trial_0.30:	Patron[30]@    1:	744
# INFO:Malasana_trial_0.30:	Patron[30]@    1:	1060
# INFO:Malasana_trial_0.30:	Patron[30]@    1:	170
# INFO:Malasana_trial_0.30:	Patron[30]@    1:	1036
# INFO:Malasana_trial_0.30:	Patron[30]@    1:	445
# INFO:Malasana_trial_0.30:	Patron[30]@    1:	979
# INFO:Malasana_trial_0.30:	Patron[30]@    1:	189
# INFO:Malasana_trial_0.31:	Patron[31]@    1:	I am looking for friends
# INFO:Malasana_trial_0.31:	Patron[31]@    1:	Now we are a group:
# INFO:Malasana_trial_0.31:	Patron[31]@    1:	1100
# INFO:Malasana_trial_0.31:	Patron[31]@    1:	913
# INFO:Malasana_trial_0.31:	Patron[31]@    1:	761
# INFO:Malasana_trial_0.31:	Patron[31]@    1:	1067
# INFO:Malasana_trial_0.31:	Patron[31]@    1:	1180
# INFO:Malasana_trial_0.31:	Patron[31]@    1:	351
# INFO:Malasana_trial_0.32:	Patron[32]@    1:	I am looking for friends
# INFO:Malasana_trial_0.32:	Patron[32]@    1:	Now we are a group:
# INFO:Malasana_trial_0.32:	Patron[32]@    1:	352
# INFO:Malasana_trial_0.32:	Patron[32]@    1:	1282
# INFO:Malasana_trial_0.32:	Patron[32]@    1:	1461
# INFO:Malasana_trial_0.32:	Patron[32]@    1:	503
# INFO:Malasana_trial_0.32:	Patron[32]@    1:	984
# INFO:Malasana_trial_0.32:	Patron[32]@    1:	409
# INFO:Malasana_trial_0.32:	Patron[32]@    1:	970
# INFO:Malasana_trial_0.32:	Patron[32]@    1:	653
# INFO:Malasana_trial_0.32:	Patron[32]@    1:	478
# INFO:Malasana_trial_0.32:	Patron[32]@    1:	399
# INFO:Malasana_trial_0.33:	Patron[33]@    1:	I am looking for friends
# INFO:Malasana_trial_0.33:	Patron[33]@    1:	Now we are a group:
# INFO:Malasana_trial_0.33:	Patron[33]@    1:	737
# INFO:Malasana_trial_0.33:	Patron[33]@    1:	1427
# INFO:Malasana_trial_0.33:	Patron[33]@    1:	1348
# INFO:Malasana_trial_0.33:	Patron[33]@    1:	1397
# INFO:Malasana_trial_0.33:	Patron[33]@    1:	294
# INFO:Malasana_trial_0.33:	Patron[33]@    1:	1192
# INFO:Malasana_trial_0.33:	Patron[33]@    1:	329
# INFO:Malasana_trial_0.33:	Patron[33]@    1:	459
# INFO:Malasana_trial_0.33:	Patron[33]@    1:	1435
# INFO:Malasana_trial_0.33:	Patron[33]@    1:	302
# INFO:Malasana_trial_0.34:	Patron[34]@    1:	I am looking for friends
# INFO:Malasana_trial_0.34:	Patron[34]@    1:	Now we are a group:
# INFO:Malasana_trial_0.34:	Patron[34]@    1:	1008
# INFO:Malasana_trial_0.34:	Patron[34]@    1:	819
# INFO:Malasana_trial_0.34:	Patron[34]@    1:	566
# INFO:Malasana_trial_0.34:	Patron[34]@    1:	777
# INFO:Malasana_trial_0.34:	Patron[34]@    1:	1193
# INFO:Malasana_trial_0.34:	Patron[34]@    1:	890
# INFO:Malasana_trial_0.34:	Patron[34]@    1:	1211
# INFO:Malasana_trial_0.34:	Patron[34]@    1:	940
# INFO:Malasana_trial_0.34:	Patron[34]@    1:	781
# INFO:Malasana_trial_0.36:	Patron[36]@    1:	I am looking for friends
# INFO:Malasana_trial_0.36:	Patron[36]@    1:	Now we are a group:
# INFO:Malasana_trial_0.36:	Patron[36]@    1:	1352
# INFO:Malasana_trial_0.36:	Patron[36]@    1:	268
# INFO:Malasana_trial_0.36:	Patron[36]@    1:	471
# INFO:Malasana_trial_0.36:	Patron[36]@    1:	1092
# INFO:Malasana_trial_0.36:	Patron[36]@    1:	167
# INFO:Malasana_trial_0.37:	Patron[37]@    1:	I am looking for friends
# INFO:Malasana_trial_0.37:	Patron[37]@    1:	Now we are a group:
# INFO:Malasana_trial_0.37:	Patron[37]@    1:	766
# INFO:Malasana_trial_0.37:	Patron[37]@    1:	1027
# INFO:Malasana_trial_0.37:	Patron[37]@    1:	489
# INFO:Malasana_trial_0.37:	Patron[37]@    1:	1259
# INFO:Malasana_trial_0.37:	Patron[37]@    1:	620
# INFO:Malasana_trial_0.37:	Patron[37]@    1:	1325
# INFO:Malasana_trial_0.37:	Patron[37]@    1:	686
# INFO:Malasana_trial_0.37:	Patron[37]@    1:	48
# INFO:Malasana_trial_0.37:	Patron[37]@    1:	899
# INFO:Malasana_trial_0.37:	Patron[37]@    1:	1269
# INFO:Malasana_trial_0.37:	Patron[37]@    1:	726
# INFO:Malasana_trial_0.37:	Patron[37]@    1:	312
# INFO:Malasana_trial_0.37:	Patron[37]@    1:	185
# INFO:Malasana_trial_0.37:	Patron[37]@    1:	1406
# INFO:Malasana_trial_0.38:	Patron[38]@    1:	I am looking for friends
# INFO:Malasana_trial_0.38:	Patron[38]@    1:	Now we are a group:
# INFO:Malasana_trial_0.38:	Patron[38]@    1:	1184
# INFO:Malasana_trial_0.38:	Patron[38]@    1:	1445
# INFO:Malasana_trial_0.38:	Patron[38]@    1:	1096
# INFO:Malasana_trial_0.38:	Patron[38]@    1:	780
# INFO:Malasana_trial_0.38:	Patron[38]@    1:	76
# INFO:Malasana_trial_0.38:	Patron[38]@    1:	526
# INFO:Malasana_trial_0.38:	Patron[38]@    1:	1232
# INFO:Malasana_trial_0.38:	Patron[38]@    1:	370
# INFO:Malasana_trial_0.38:	Patron[38]@    1:	174
# INFO:Malasana_trial_0.38:	Patron[38]@    1:	182
# INFO:Malasana_trial_0.38:	Patron[38]@    1:	1431
# INFO:Malasana_trial_0.38:	Patron[38]@    1:	120
# INFO:Malasana_trial_0.38:	Patron[38]@    1:	1114
# INFO:Malasana_trial_0.39:	Patron[39]@    1:	I am looking for friends
# INFO:Malasana_trial_0.39:	Patron[39]@    1:	Now we are a group:
# INFO:Malasana_trial_0.39:	Patron[39]@    1:	533
# INFO:Malasana_trial_0.39:	Patron[39]@    1:	1095
# INFO:Malasana_trial_0.39:	Patron[39]@    1:	808
# INFO:Malasana_trial_0.39:	Patron[39]@    1:	330
# INFO:Malasana_trial_0.39:	Patron[39]@    1:	715
# INFO:Malasana_trial_0.39:	Patron[39]@    1:	188
# INFO:Malasana_trial_0.39:	Patron[39]@    1:	493
# INFO:Malasana_trial_0.39:	Patron[39]@    1:	1450
# INFO:Malasana_trial_0.41:	Patron[41]@    1:	I am looking for friends
# INFO:Malasana_trial_0.41:	Patron[41]@    1:	Now we are a group:
# INFO:Malasana_trial_0.41:	Patron[41]@    1:	1025
# INFO:Malasana_trial_0.41:	Patron[41]@    1:	1395
# INFO:Malasana_trial_0.41:	Patron[41]@    1:	1028
# INFO:Malasana_trial_0.41:	Patron[41]@    1:	1159
# INFO:Malasana_trial_0.41:	Patron[41]@    1:	1143
# INFO:Malasana_trial_0.41:	Patron[41]@    1:	58
# INFO:Malasana_trial_0.41:	Patron[41]@    1:	1151
# INFO:Malasana_trial_0.41:	Patron[41]@    1:	316
# INFO:Malasana_trial_0.41:	Patron[41]@    1:	286
# INFO:Malasana_trial_0.41:	Patron[41]@    1:	991
# INFO:Malasana_trial_0.42:	Patron[42]@    1:	I am looking for friends
# INFO:Malasana_trial_0.42:	Patron[42]@    1:	Now we are a group:
# INFO:Malasana_trial_0.42:	Patron[42]@    1:	193
# INFO:Malasana_trial_0.42:	Patron[42]@    1:	194
# INFO:Malasana_trial_0.42:	Patron[42]@    1:	507
# INFO:Malasana_trial_0.42:	Patron[42]@    1:	1126
# INFO:Malasana_trial_0.42:	Patron[42]@    1:	321
# INFO:Malasana_trial_0.42:	Patron[42]@    1:	234
# INFO:Malasana_trial_0.42:	Patron[42]@    1:	1410
# INFO:Malasana_trial_0.42:	Patron[42]@    1:	654
# INFO:Malasana_trial_0.42:	Patron[42]@    1:	573
# INFO:Malasana_trial_0.42:	Patron[42]@    1:	720
# INFO:Malasana_trial_0.42:	Patron[42]@    1:	1172
# INFO:Malasana_trial_0.42:	Patron[42]@    1:	568
# INFO:Malasana_trial_0.42:	Patron[42]@    1:	891
# INFO:Malasana_trial_0.42:	Patron[42]@    1:	956
# INFO:Malasana_trial_0.42:	Patron[42]@    1:	1053
# INFO:Malasana_trial_0.45:	Patron[45]@    1:	I am looking for friends
# INFO:Malasana_trial_0.45:	Patron[45]@    1:	Now we are a group:
# INFO:Malasana_trial_0.45:	Patron[45]@    1:	528
# INFO:Malasana_trial_0.45:	Patron[45]@    1:	1218
# INFO:Malasana_trial_0.45:	Patron[45]@    1:	900
# INFO:Malasana_trial_0.45:	Patron[45]@    1:	181
# INFO:Malasana_trial_0.45:	Patron[45]@    1:	889
# INFO:Malasana_trial_0.45:	Patron[45]@    1:	552
# INFO:Malasana_trial_0.45:	Patron[45]@    1:	1372
# INFO:Malasana_trial_0.45:	Patron[45]@    1:	1228
# INFO:Malasana_trial_0.45:	Patron[45]@    1:	301
# INFO:Malasana_trial_0.45:	Patron[45]@    1:	78
# INFO:Malasana_trial_0.45:	Patron[45]@    1:	405
# INFO:Malasana_trial_0.46:	Patron[46]@    1:	I am looking for friends
# INFO:Malasana_trial_0.46:	Patron[46]@    1:	Now we are a group:
# INFO:Malasana_trial_0.46:	Patron[46]@    1:	1016
# INFO:Malasana_trial_0.46:	Patron[46]@    1:	579
# INFO:Malasana_trial_0.46:	Patron[46]@    1:	546
# INFO:Malasana_trial_0.46:	Patron[46]@    1:	75
# INFO:Malasana_trial_0.46:	Patron[46]@    1:	723
# INFO:Malasana_trial_0.49:	Patron[49]@    1:	I am looking for friends
# INFO:Malasana_trial_0.49:	Patron[49]@    1:	Now we are a group:
# INFO:Malasana_trial_0.49:	Patron[49]@    1:	482
# INFO:Malasana_trial_0.49:	Patron[49]@    1:	867
# INFO:Malasana_trial_0.49:	Patron[49]@    1:	871
# INFO:Malasana_trial_0.49:	Patron[49]@    1:	680
# INFO:Malasana_trial_0.49:	Patron[49]@    1:	490
# INFO:Malasana_trial_0.49:	Patron[49]@    1:	462
# INFO:Malasana_trial_0.49:	Patron[49]@    1:	111
# INFO:Malasana_trial_0.49:	Patron[49]@    1:	624
# INFO:Malasana_trial_0.49:	Patron[49]@    1:	1213
# INFO:Malasana_trial_0.49:	Patron[49]@    1:	1309
# INFO:Malasana_trial_0.49:	Patron[49]@    1:	1208
# INFO:Malasana_trial_0.49:	Patron[49]@    1:	313
# INFO:Malasana_trial_0.49:	Patron[49]@    1:	106
# INFO:Malasana_trial_0.51:	Patron[51]@    1:	I am looking for friends
# INFO:Malasana_trial_0.51:	Patron[51]@    1:	Now we are a group:
# INFO:Malasana_trial_0.51:	Patron[51]@    1:	280
# INFO:Malasana_trial_0.51:	Patron[51]@    1:	515
# INFO:Malasana_trial_0.51:	Patron[51]@    1:	789
# INFO:Malasana_trial_0.51:	Patron[51]@    1:	649
# INFO:Malasana_trial_0.51:	Patron[51]@    1:	920
# INFO:Malasana_trial_0.51:	Patron[51]@    1:	665
# INFO:Malasana_trial_0.51:	Patron[51]@    1:	266
# INFO:Malasana_trial_0.51:	Patron[51]@    1:	796
# INFO:Malasana_trial_0.51:	Patron[51]@    1:	597
# INFO:Malasana_trial_0.52:	Patron[52]@    1:	I am looking for friends
# INFO:Malasana_trial_0.52:	Patron[52]@    1:	Now we are a group:
# INFO:Malasana_trial_0.52:	Patron[52]@    1:	1376
# INFO:Malasana_trial_0.52:	Patron[52]@    1:	1200
# INFO:Malasana_trial_0.52:	Patron[52]@    1:	1467
# INFO:Malasana_trial_0.52:	Patron[52]@    1:	245
# INFO:Malasana_trial_0.52:	Patron[52]@    1:	219
# INFO:Malasana_trial_0.52:	Patron[52]@    1:	1275
# INFO:Malasana_trial_0.52:	Patron[52]@    1:	332
# INFO:Malasana_trial_0.52:	Patron[52]@    1:	221
# INFO:Malasana_trial_0.52:	Patron[52]@    1:	1070
# INFO:Malasana_trial_0.52:	Patron[52]@    1:	895
# INFO:Malasana_trial_0.53:	Patron[53]@    1:	I am looking for friends
# INFO:Malasana_trial_0.53:	Patron[53]@    1:	Now we are a group:
# INFO:Malasana_trial_0.53:	Patron[53]@    1:	929
# INFO:Malasana_trial_0.53:	Patron[53]@    1:	1058
# INFO:Malasana_trial_0.53:	Patron[53]@    1:	1085
# INFO:Malasana_trial_0.53:	Patron[53]@    1:	548
# INFO:Malasana_trial_0.53:	Patron[53]@    1:	518
# INFO:Malasana_trial_0.53:	Patron[53]@    1:	1421
# INFO:Malasana_trial_0.53:	Patron[53]@    1:	527
# INFO:Malasana_trial_0.53:	Patron[53]@    1:	1459
# INFO:Malasana_trial_0.53:	Patron[53]@    1:	1298
# INFO:Malasana_trial_0.53:	Patron[53]@    1:	563
# INFO:Malasana_trial_0.53:	Patron[53]@    1:	1178
# INFO:Malasana_trial_0.53:	Patron[53]@    1:	56
# INFO:Malasana_trial_0.53:	Patron[53]@    1:	1498
# INFO:Malasana_trial_0.53:	Patron[53]@    1:	61
# INFO:Malasana_trial_0.54:	Patron[54]@    1:	I am looking for friends
# INFO:Malasana_trial_0.54:	Patron[54]@    1:	Now we are a group:
# INFO:Malasana_trial_0.54:	Patron[54]@    1:	1392
# INFO:Malasana_trial_0.54:	Patron[54]@    1:	562
# INFO:Malasana_trial_0.54:	Patron[54]@    1:	1443
# INFO:Malasana_trial_0.54:	Patron[54]@    1:	901
# INFO:Malasana_trial_0.54:	Patron[54]@    1:	89
# INFO:Malasana_trial_0.54:	Patron[54]@    1:	250
# INFO:Malasana_trial_0.54:	Patron[54]@    1:	191
# INFO:Malasana_trial_0.55:	Patron[55]@    1:	I am looking for friends
# INFO:Malasana_trial_0.55:	Patron[55]@    1:	Now we are a group:
# INFO:Malasana_trial_0.55:	Patron[55]@    1:	817
# INFO:Malasana_trial_0.55:	Patron[55]@    1:	1319
# INFO:Malasana_trial_0.55:	Patron[55]@    1:	535
# INFO:Malasana_trial_0.55:	Patron[55]@    1:	153
# INFO:Malasana_trial_0.55:	Patron[55]@    1:	1354
# INFO:Malasana_trial_0.55:	Patron[55]@    1:	651
# INFO:Malasana_trial_0.55:	Patron[55]@    1:	300
# INFO:Malasana_trial_0.55:	Patron[55]@    1:	158
# INFO:Malasana_trial_0.55:	Patron[55]@    1:	607
# INFO:Malasana_trial_0.60:	Patron[60]@    1:	I am looking for friends
# INFO:Malasana_trial_0.60:	Patron[60]@    1:	Now we are a group:
# INFO:Malasana_trial_0.60:	Patron[60]@    1:	1065
# INFO:Malasana_trial_0.60:	Patron[60]@    1:	274
# INFO:Malasana_trial_0.60:	Patron[60]@    1:	509
# INFO:Malasana_trial_0.60:	Patron[60]@    1:	1134
# INFO:Malasana_trial_0.62:	Patron[62]@    1:	I am looking for friends
# INFO:Malasana_trial_0.62:	Patron[62]@    1:	Now we are a group:
# INFO:Malasana_trial_0.62:	Patron[62]@    1:	242
# INFO:Malasana_trial_0.62:	Patron[62]@    1:	595
# INFO:Malasana_trial_0.62:	Patron[62]@    1:	677
# INFO:Malasana_trial_0.62:	Patron[62]@    1:	102
# INFO:Malasana_trial_0.62:	Patron[62]@    1:	791
# INFO:Malasana_trial_0.62:	Patron[62]@    1:	1128
# INFO:Malasana_trial_0.62:	Patron[62]@    1:	470
# INFO:Malasana_trial_0.62:	Patron[62]@    1:	299
# INFO:Malasana_trial_0.62:	Patron[62]@    1:	1436
# INFO:Malasana_trial_0.62:	Patron[62]@    1:	238
# INFO:Malasana_trial_0.63:	Patron[63]@    1:	I am looking for friends
# INFO:Malasana_trial_0.63:	Patron[63]@    1:	Now we are a group:
# INFO:Malasana_trial_0.63:	Patron[63]@    1:	273
# INFO:Malasana_trial_0.63:	Patron[63]@    1:	267
# INFO:Malasana_trial_0.63:	Patron[63]@    1:	774
# INFO:Malasana_trial_0.63:	Patron[63]@    1:	1478
# INFO:Malasana_trial_0.64:	Patron[64]@    1:	I am looking for friends
# INFO:Malasana_trial_0.64:	Patron[64]@    1:	Now we are a group:
# INFO:Malasana_trial_0.64:	Patron[64]@    1:	594
# INFO:Malasana_trial_0.64:	Patron[64]@    1:	1139
# INFO:Malasana_trial_0.64:	Patron[64]@    1:	1318
# INFO:Malasana_trial_0.64:	Patron[64]@    1:	694
# INFO:Malasana_trial_0.64:	Patron[64]@    1:	442
# INFO:Malasana_trial_0.64:	Patron[64]@    1:	1227
# INFO:Malasana_trial_0.64:	Patron[64]@    1:	709
# INFO:Malasana_trial_0.65:	Patron[65]@    1:	I am looking for friends
# INFO:Malasana_trial_0.65:	Patron[65]@    1:	Now we are a group:
# INFO:Malasana_trial_0.65:	Patron[65]@    1:	678
# INFO:Malasana_trial_0.65:	Patron[65]@    1:	521
# INFO:Malasana_trial_0.65:	Patron[65]@    1:	339
# INFO:Malasana_trial_0.65:	Patron[65]@    1:	1331
# INFO:Malasana_trial_0.65:	Patron[65]@    1:	205
# INFO:Malasana_trial_0.65:	Patron[65]@    1:	1165
# INFO:Malasana_trial_0.65:	Patron[65]@    1:	434
# INFO:Malasana_trial_0.65:	Patron[65]@    1:	1171
# INFO:Malasana_trial_0.65:	Patron[65]@    1:	755
# INFO:Malasana_trial_0.65:	Patron[65]@    1:	1365
# INFO:Malasana_trial_0.65:	Patron[65]@    1:	873
# INFO:Malasana_trial_0.65:	Patron[65]@    1:	1337
# INFO:Malasana_trial_0.65:	Patron[65]@    1:	187
# INFO:Malasana_trial_0.65:	Patron[65]@    1:	1423
# INFO:Malasana_trial_0.66:	Patron[66]@    1:	I am looking for friends
# INFO:Malasana_trial_0.66:	Patron[66]@    1:	Now we are a group:
# INFO:Malasana_trial_0.66:	Patron[66]@    1:	160
# INFO:Malasana_trial_0.66:	Patron[66]@    1:	1312
# INFO:Malasana_trial_0.66:	Patron[66]@    1:	1346
# INFO:Malasana_trial_0.66:	Patron[66]@    1:	580
# INFO:Malasana_trial_0.66:	Patron[66]@    1:	438
# INFO:Malasana_trial_0.66:	Patron[66]@    1:	1175
# INFO:Malasana_trial_0.66:	Patron[66]@    1:	952
# INFO:Malasana_trial_0.66:	Patron[66]@    1:	169
# INFO:Malasana_trial_0.66:	Patron[66]@    1:	429
# INFO:Malasana_trial_0.66:	Patron[66]@    1:	367
# INFO:Malasana_trial_0.67:	Patron[67]@    1:	I am looking for friends
# INFO:Malasana_trial_0.67:	Patron[67]@    1:	Now we are a group:
# INFO:Malasana_trial_0.67:	Patron[67]@    1:	912
# INFO:Malasana_trial_0.67:	Patron[67]@    1:	385
# INFO:Malasana_trial_0.67:	Patron[67]@    1:	1202
# INFO:Malasana_trial_0.67:	Patron[67]@    1:	71
# INFO:Malasana_trial_0.67:	Patron[67]@    1:	904
# INFO:Malasana_trial_0.67:	Patron[67]@    1:	569
# INFO:Malasana_trial_0.67:	Patron[67]@    1:	615
# INFO:Malasana_trial_0.67:	Patron[67]@    1:	1442
# INFO:Malasana_trial_0.67:	Patron[67]@    1:	590
# INFO:Malasana_trial_0.67:	Patron[67]@    1:	1103
# INFO:Malasana_trial_0.68:	Patron[68]@    1:	I am looking for friends
# INFO:Malasana_trial_0.68:	Patron[68]@    1:	Now we are a group:
# INFO:Malasana_trial_0.68:	Patron[68]@    1:	1059
# INFO:Malasana_trial_0.68:	Patron[68]@    1:	708
# INFO:Malasana_trial_0.68:	Patron[68]@    1:	425
# INFO:Malasana_trial_0.68:	Patron[68]@    1:	452
# INFO:Malasana_trial_0.68:	Patron[68]@    1:	419
# INFO:Malasana_trial_0.68:	Patron[68]@    1:	1375
# INFO:Malasana_trial_0.70:	Patron[70]@    1:	I am looking for friends
# INFO:Malasana_trial_0.70:	Patron[70]@    1:	Now we are a group:
# INFO:Malasana_trial_0.70:	Patron[70]@    1:	1177
# INFO:Malasana_trial_0.70:	Patron[70]@    1:	1247
# INFO:Malasana_trial_0.70:	Patron[70]@    1:	756
# INFO:Malasana_trial_0.70:	Patron[70]@    1:	1110
# INFO:Malasana_trial_0.70:	Patron[70]@    1:	215
# INFO:Malasana_trial_0.73:	Patron[73]@    1:	I am looking for friends
# INFO:Malasana_trial_0.73:	Patron[73]@    1:	Now we are a group:
# INFO:Malasana_trial_0.73:	Patron[73]@    1:	752
# INFO:Malasana_trial_0.73:	Patron[73]@    1:	497
# INFO:Malasana_trial_0.73:	Patron[73]@    1:	307
# INFO:Malasana_trial_0.73:	Patron[73]@    1:	180
# INFO:Malasana_trial_0.73:	Patron[73]@    1:	1251
# INFO:Malasana_trial_0.73:	Patron[73]@    1:	758
# INFO:Malasana_trial_0.73:	Patron[73]@    1:	551
# INFO:Malasana_trial_0.73:	Patron[73]@    1:	634
# INFO:Malasana_trial_0.73:	Patron[73]@    1:	379
# INFO:Malasana_trial_0.73:	Patron[73]@    1:	542
# INFO:Malasana_trial_0.74:	Patron[74]@    1:	I am looking for friends
# INFO:Malasana_trial_0.74:	Patron[74]@    1:	Now we are a group:
# INFO:Malasana_trial_0.74:	Patron[74]@    1:	1185
# INFO:Malasana_trial_0.74:	Patron[74]@    1:	733
# INFO:Malasana_trial_0.74:	Patron[74]@    1:	1454
# INFO:Malasana_trial_0.74:	Patron[74]@    1:	1462
# INFO:Malasana_trial_0.74:	Patron[74]@    1:	982
# INFO:Malasana_trial_0.74:	Patron[74]@    1:	938
# INFO:Malasana_trial_0.74:	Patron[74]@    1:	1311
# INFO:Malasana_trial_0.74:	Patron[74]@    1:	669
# INFO:Malasana_trial_0.74:	Patron[74]@    1:	1246
# INFO:Malasana_trial_0.74:	Patron[74]@    1:	1466
# INFO:Malasana_trial_0.77:	Patron[77]@    1:	I am looking for friends
# INFO:Malasana_trial_0.77:	Patron[77]@    1:	Now we are a group:
# INFO:Malasana_trial_0.77:	Patron[77]@    1:	828
# INFO:Malasana_trial_0.77:	Patron[77]@    1:	1122
# INFO:Malasana_trial_0.77:	Patron[77]@    1:	964
# INFO:Malasana_trial_0.77:	Patron[77]@    1:	134
# INFO:Malasana_trial_0.79:	Patron[79]@    1:	I am looking for friends
# INFO:Malasana_trial_0.79:	Patron[79]@    1:	Now we are a group:
# INFO:Malasana_trial_0.79:	Patron[79]@    1:	1299
# INFO:Malasana_trial_0.79:	Patron[79]@    1:	948
# INFO:Malasana_trial_0.79:	Patron[79]@    1:	166
# INFO:Malasana_trial_0.80:	Patron[80]@    1:	I am looking for friends
# INFO:Malasana_trial_0.80:	Patron[80]@    1:	Now we are a group:
# INFO:Malasana_trial_0.80:	Patron[80]@    1:	1152
# INFO:Malasana_trial_0.80:	Patron[80]@    1:	1327
# INFO:Malasana_trial_0.80:	Patron[80]@    1:	195
# INFO:Malasana_trial_0.80:	Patron[80]@    1:	309
# INFO:Malasana_trial_0.80:	Patron[80]@    1:	1286
# INFO:Malasana_trial_0.80:	Patron[80]@    1:	1066
# INFO:Malasana_trial_0.80:	Patron[80]@    1:	955
# INFO:Malasana_trial_0.80:	Patron[80]@    1:	1296
# INFO:Malasana_trial_0.80:	Patron[80]@    1:	239
# INFO:Malasana_trial_0.81:	Patron[81]@    1:	I am looking for friends
# INFO:Malasana_trial_0.81:	Patron[81]@    1:	Now we are a group:
# INFO:Malasana_trial_0.81:	Patron[81]@    1:	192
# INFO:Malasana_trial_0.81:	Patron[81]@    1:	133
# INFO:Malasana_trial_0.81:	Patron[81]@    1:	406
# INFO:Malasana_trial_0.81:	Patron[81]@    1:	1351
# INFO:Malasana_trial_0.81:	Patron[81]@    1:	1384
# INFO:Malasana_trial_0.81:	Patron[81]@    1:	288
# INFO:Malasana_trial_0.81:	Patron[81]@    1:	1007
# INFO:Malasana_trial_0.81:	Patron[81]@    1:	986
# INFO:Malasana_trial_0.81:	Patron[81]@    1:	1044
# INFO:Malasana_trial_0.81:	Patron[81]@    1:	373
# INFO:Malasana_trial_0.81:	Patron[81]@    1:	1430
# INFO:Malasana_trial_0.81:	Patron[81]@    1:	1370
# INFO:Malasana_trial_0.81:	Patron[81]@    1:	671
# INFO:Malasana_trial_0.81:	Patron[81]@    1:	925
# INFO:Malasana_trial_0.81:	Patron[81]@    1:	821
# INFO:Malasana_trial_0.82:	Patron[82]@    1:	I am looking for friends
# INFO:Malasana_trial_0.82:	Patron[82]@    1:	Now we are a group:
# INFO:Malasana_trial_0.82:	Patron[82]@    1:	951
# INFO:Malasana_trial_0.82:	Patron[82]@    1:	701
# INFO:Malasana_trial_0.82:	Patron[82]@    1:	531
# INFO:Malasana_trial_0.82:	Patron[82]@    1:	165
# INFO:Malasana_trial_0.82:	Patron[82]@    1:	231
# INFO:Malasana_trial_0.82:	Patron[82]@    1:	1418
# INFO:Malasana_trial_0.82:	Patron[82]@    1:	631
# INFO:Malasana_trial_0.82:	Patron[82]@    1:	1308
# INFO:Malasana_trial_0.82:	Patron[82]@    1:	157
# INFO:Malasana_trial_0.82:	Patron[82]@    1:	622
# INFO:Malasana_trial_0.82:	Patron[82]@    1:	927
# INFO:Malasana_trial_0.83:	Patron[83]@    1:	I am looking for friends
# INFO:Malasana_trial_0.83:	Patron[83]@    1:	Now we are a group:
# INFO:Malasana_trial_0.83:	Patron[83]@    1:	1387
# INFO:Malasana_trial_0.83:	Patron[83]@    1:	1124
# INFO:Malasana_trial_0.83:	Patron[83]@    1:	517
# INFO:Malasana_trial_0.83:	Patron[83]@    1:	486
# INFO:Malasana_trial_0.83:	Patron[83]@    1:	327
# INFO:Malasana_trial_0.83:	Patron[83]@    1:	775
# INFO:Malasana_trial_0.83:	Patron[83]@    1:	812
# INFO:Malasana_trial_0.83:	Patron[83]@    1:	1486
# INFO:Malasana_trial_0.83:	Patron[83]@    1:	724
# INFO:Malasana_trial_0.83:	Patron[83]@    1:	1494
# INFO:Malasana_trial_0.83:	Patron[83]@    1:	1495
# INFO:Malasana_trial_0.83:	Patron[83]@    1:	792
# INFO:Malasana_trial_0.83:	Patron[83]@    1:	985
# INFO:Malasana_trial_0.83:	Patron[83]@    1:	1055
# INFO:Malasana_trial_0.84:	Patron[84]@    1:	I am looking for friends
# INFO:Malasana_trial_0.84:	Patron[84]@    1:	Now we are a group:
# INFO:Malasana_trial_0.84:	Patron[84]@    1:	1088
# INFO:Malasana_trial_0.84:	Patron[84]@    1:	1377
# INFO:Malasana_trial_0.84:	Patron[84]@    1:	354
# INFO:Malasana_trial_0.84:	Patron[84]@    1:	451
# INFO:Malasana_trial_0.84:	Patron[84]@    1:	260
# INFO:Malasana_trial_0.84:	Patron[84]@    1:	323
# INFO:Malasana_trial_0.84:	Patron[84]@    1:	1455
# INFO:Malasana_trial_0.84:	Patron[84]@    1:	882
# INFO:Malasana_trial_0.84:	Patron[84]@    1:	211
# INFO:Malasana_trial_0.84:	Patron[84]@    1:	1363
# INFO:Malasana_trial_0.84:	Patron[84]@    1:	740
# INFO:Malasana_trial_0.84:	Patron[84]@    1:	118
# INFO:Malasana_trial_0.84:	Patron[84]@    1:	804
# INFO:Malasana_trial_0.84:	Patron[84]@    1:	1021
# INFO:Malasana_trial_0.86:	Patron[86]@    1:	I am looking for friends
# INFO:Malasana_trial_0.86:	Patron[86]@    1:	Now we are a group:
# INFO:Malasana_trial_0.86:	Patron[86]@    1:	1248
# INFO:Malasana_trial_0.86:	Patron[86]@    1:	961
# INFO:Malasana_trial_0.86:	Patron[86]@    1:	613
# INFO:Malasana_trial_0.86:	Patron[86]@    1:	230
# INFO:Malasana_trial_0.86:	Patron[86]@    1:	1009
# INFO:Malasana_trial_0.86:	Patron[86]@    1:	716
# INFO:Malasana_trial_0.86:	Patron[86]@    1:	831
# INFO:Malasana_trial_0.86:	Patron[86]@    1:	646
# INFO:Malasana_trial_0.86:	Patron[86]@    1:	432
# INFO:Malasana_trial_0.86:	Patron[86]@    1:	433
# INFO:Malasana_trial_0.86:	Patron[86]@    1:	1274
# INFO:Malasana_trial_0.86:	Patron[86]@    1:	827
# INFO:Malasana_trial_0.86:	Patron[86]@    1:	284
# INFO:Malasana_trial_0.86:	Patron[86]@    1:	453
# INFO:Malasana_trial_0.88:	Patron[88]@    1:	I am looking for friends
# INFO:Malasana_trial_0.88:	Patron[88]@    1:	Now we are a group:
# INFO:Malasana_trial_0.88:	Patron[88]@    1:	304
# INFO:Malasana_trial_0.88:	Patron[88]@    1:	928
# INFO:Malasana_trial_0.88:	Patron[88]@    1:	1011
# INFO:Malasana_trial_0.88:	Patron[88]@    1:	388
# INFO:Malasana_trial_0.88:	Patron[88]@    1:	538
# INFO:Malasana_trial_0.88:	Patron[88]@    1:	575
# INFO:Malasana_trial_0.90:	Patron[90]@    1:	I am looking for friends
# INFO:Malasana_trial_0.90:	Patron[90]@    1:	Now we are a group:
# INFO:Malasana_trial_0.90:	Patron[90]@    1:	642
# INFO:Malasana_trial_0.90:	Patron[90]@    1:	707
# INFO:Malasana_trial_0.90:	Patron[90]@    1:	1029
# INFO:Malasana_trial_0.90:	Patron[90]@    1:	1063
# INFO:Malasana_trial_0.90:	Patron[90]@    1:	872
# INFO:Malasana_trial_0.90:	Patron[90]@    1:	362
# INFO:Malasana_trial_0.90:	Patron[90]@    1:	834
# INFO:Malasana_trial_0.90:	Patron[90]@    1:	1453
# INFO:Malasana_trial_0.90:	Patron[90]@    1:	1378
# INFO:Malasana_trial_0.90:	Patron[90]@    1:	786
# INFO:Malasana_trial_0.90:	Patron[90]@    1:	1043
# INFO:Malasana_trial_0.90:	Patron[90]@    1:	1396
# INFO:Malasana_trial_0.90:	Patron[90]@    1:	987
# INFO:Malasana_trial_0.91:	Patron[91]@    1:	I am looking for friends
# INFO:Malasana_trial_0.91:	Patron[91]@    1:	Now we are a group:
# INFO:Malasana_trial_0.91:	Patron[91]@    1:	1472
# INFO:Malasana_trial_0.91:	Patron[91]@    1:	816
# INFO:Malasana_trial_0.91:	Patron[91]@    1:	235
# INFO:Malasana_trial_0.91:	Patron[91]@    1:	132
# INFO:Malasana_trial_0.91:	Patron[91]@    1:	769
# INFO:Malasana_trial_0.91:	Patron[91]@    1:	504
# INFO:Malasana_trial_0.91:	Patron[91]@    1:	652
# INFO:Malasana_trial_0.91:	Patron[91]@    1:	570
# INFO:Malasana_trial_0.91:	Patron[91]@    1:	779
# INFO:Malasana_trial_0.91:	Patron[91]@    1:	220
# INFO:Malasana_trial_0.91:	Patron[91]@    1:	1262
# INFO:Malasana_trial_0.94:	Patron[94]@    1:	I am looking for friends
# INFO:Malasana_trial_0.94:	Patron[94]@    1:	Now we are a group:
# INFO:Malasana_trial_0.94:	Patron[94]@    1:	1345
# INFO:Malasana_trial_0.94:	Patron[94]@    1:	290
# INFO:Malasana_trial_0.94:	Patron[94]@    1:	115
# INFO:Malasana_trial_0.94:	Patron[94]@    1:	1076
# INFO:Malasana_trial_0.94:	Patron[94]@    1:	1287
# INFO:Malasana_trial_0.94:	Patron[94]@    1:	712
# INFO:Malasana_trial_0.94:	Patron[94]@    1:	1188
# INFO:Malasana_trial_0.94:	Patron[94]@    1:	468
# INFO:Malasana_trial_0.94:	Patron[94]@    1:	973
# INFO:Malasana_trial_0.94:	Patron[94]@    1:	1166
# INFO:Malasana_trial_0.95:	Patron[95]@    1:	I am looking for friends
# INFO:Malasana_trial_0.95:	Patron[95]@    1:	Now we are a group:
# INFO:Malasana_trial_0.95:	Patron[95]@    1:	641
# INFO:Malasana_trial_0.95:	Patron[95]@    1:	612
# INFO:Malasana_trial_0.95:	Patron[95]@    1:	1479
# INFO:Malasana_trial_0.95:	Patron[95]@    1:	1244
# INFO:Malasana_trial_0.95:	Patron[95]@    1:	586
# INFO:Malasana_trial_0.95:	Patron[95]@    1:	1214
# INFO:Malasana_trial_0.95:	Patron[95]@    1:	655
# INFO:Malasana_trial_0.95:	Patron[95]@    1:	212
# INFO:Malasana_trial_0.95:	Patron[95]@    1:	798
# INFO:Malasana_trial_0.95:	Patron[95]@    1:	730
# INFO:Malasana_trial_0.95:	Patron[95]@    1:	667
# INFO:Malasana_trial_0.95:	Patron[95]@    1:	252
# INFO:Malasana_trial_0.95:	Patron[95]@    1:	606
# INFO:Malasana_trial_0.96:	Patron[96]@    1:	I am looking for friends
# INFO:Malasana_trial_0.96:	Patron[96]@    1:	Now we are a group:
# INFO:Malasana_trial_0.96:	Patron[96]@    1:	1217
# INFO:Malasana_trial_0.96:	Patron[96]@    1:	923
# INFO:Malasana_trial_0.96:	Patron[96]@    1:	1358
# INFO:Malasana_trial_0.96:	Patron[96]@    1:	1222
# INFO:Malasana_trial_0.96:	Patron[96]@    1:	1094
# INFO:Malasana_trial_0.98:	Patron[98]@    1:	I am looking for friends
# INFO:Malasana_trial_0.98:	Patron[98]@    1:	Now we are a group:
# INFO:Malasana_trial_0.98:	Patron[98]@    1:	611
# INFO:Malasana_trial_0.98:	Patron[98]@    1:	293
# INFO:Malasana_trial_0.98:	Patron[98]@    1:	903
# INFO:Malasana_trial_0.98:	Patron[98]@    1:	393
# INFO:Malasana_trial_0.98:	Patron[98]@    1:	746
# INFO:Malasana_trial_0.98:	Patron[98]@    1:	935
# INFO:Malasana_trial_0.98:	Patron[98]@    1:	333
# INFO:Malasana_trial_0.98:	Patron[98]@    1:	1422
# INFO:Malasana_trial_0.98:	Patron[98]@    1:	1489
# INFO:Malasana_trial_0.98:	Patron[98]@    1:	884
# INFO:Malasana_trial_0.98:	Patron[98]@    1:	1429
# INFO:Malasana_trial_0.98:	Patron[98]@    1:	1144
# INFO:Malasana_trial_0.98:	Patron[98]@    1:	1241
# INFO:Malasana_trial_0.98:	Patron[98]@    1:	475
# INFO:Malasana_trial_0.98:	Patron[98]@    1:	1469
# INFO:Malasana_trial_0.100:	Patron[100]@    1:	I am looking for friends
# INFO:Malasana_trial_0.100:	Patron[100]@    1:	Now we are a group:
# INFO:Malasana_trial_0.100:	Patron[100]@    1:	992
# INFO:Malasana_trial_0.100:	Patron[100]@    1:	993
# INFO:Malasana_trial_0.100:	Patron[100]@    1:	1140
# INFO:Malasana_trial_0.100:	Patron[100]@    1:	1109
# INFO:Malasana_trial_0.100:	Patron[100]@    1:	1447
# INFO:Malasana_trial_0.100:	Patron[100]@    1:	628
# INFO:Malasana_trial_0.100:	Patron[100]@    1:	1050
# INFO:Malasana_trial_0.100:	Patron[100]@    1:	1068
# INFO:Malasana_trial_0.100:	Patron[100]@    1:	749
# INFO:Malasana_trial_0.101:	Patron[101]@    1:	I am looking for friends
# ...
# INFO:Malasana_trial_0.1161:	Patron[1161]@   22:	El venue tenia 6 personas y ahora 5
# INFO:Malasana_trial_0.Police:	Police[Police]@   22:	El The awesome pub #7 ha cerrado con 0 personas dentro
# INFO:Malasana_trial_0.19:	Patron[19]@   23:	El venue tenia 20 personas y ahora 19
# INFO:Malasana_trial_0.60:	Patron[60]@   23:	This member is going to change venue: 60
# INFO:Malasana_trial_0.60:	Patron[60]@   23:	Al final no pudimos cambiar a ninguno y nos quedamos en este
# INFO:Malasana_trial_0.198:	Patron[198]@   23:	El venue tenia 19 personas y ahora 18
# INFO:Malasana_trial_0.411:	Patron[411]@   23:	El venue tenia 18 personas y ahora 17
# INFO:Malasana_trial_0.509:	Patron[509]@   23:	El venue tenia 7 personas y ahora 6
# INFO:Malasana_trial_0.664:	Patron[664]@   23:	El venue tenia 17 personas y ahora 16
# INFO:Malasana_trial_0.684:	Patron[684]@   23:	El venue tenia 16 personas y ahora 15
# INFO:Malasana_trial_0.876:	Patron[876]@   23:	El venue tenia 15 personas y ahora 14
# INFO:Malasana_trial_0.905:	Patron[905]@   23:	El venue tenia 14 personas y ahora 13
# INFO:Malasana_trial_0.997:	Patron[997]@   23:	El venue tenia 13 personas y ahora 12
# INFO:Malasana_trial_0.1081:	Patron[1081]@   23:	El venue tenia 12 personas y ahora 11
# INFO:Malasana_trial_0.1164:	Patron[1164]@   23:	Me voy a casa porque habíamos salido 11 y solo quedamos 5
# INFO:Malasana_trial_0.1197:	Patron[1197]@   23:	El venue tenia 11 personas y ahora 10
# INFO:Malasana_trial_0.1290:	Patron[1290]@   23:	El venue tenia 10 personas y ahora 9
# INFO:Malasana_trial_0.1306:	Patron[1306]@   23:	El venue tenia 9 personas y ahora 8
# INFO:Malasana_trial_0.1338:	Patron[1338]@   23:	El venue tenia 8 personas y ahora 7
# INFO:Malasana_trial_0.1471:	Patron[1471]@   23:	El venue tenia 7 personas y ahora 6
# INFO:Malasana_trial_0.39:	Patron[39]@   23:	El venue tenia 30 personas y ahora 29
# INFO:Malasana_trial_0.172:	Patron[172]@   23:	El venue tenia 29 personas y ahora 28
# INFO:Malasana_trial_0.188:	Patron[188]@   23:	El venue tenia 28 personas y ahora 27
# INFO:Malasana_trial_0.493:	Patron[493]@   23:	El venue tenia 27 personas y ahora 26
# INFO:Malasana_trial_0.514:	Patron[514]@   23:	Es mi hora de irme a casa
# INFO:Malasana_trial_0.529:	Patron[529]@   23:	El venue tenia 26 personas y ahora 25
# INFO:Malasana_trial_0.533:	Patron[533]@   23:	El venue tenia 25 personas y ahora 24
# INFO:Malasana_trial_0.715:	Patron[715]@   23:	No tenía bar. Me han debido hacer kick out
# INFO:Malasana_trial_0.1095:	Patron[1095]@   23:	No tenía bar. Me han debido hacer kick out
# INFO:Malasana_trial_0.1113:	Patron[1113]@   23:	Es mi hora de irme a casa
# INFO:Malasana_trial_0.70:	Patron[70]@   23:	This member is going to change venue: 70
# INFO:Malasana_trial_0.70:	Patron[70]@   23:	Al final no pudimos cambiar a ninguno y nos quedamos en este
# INFO:Malasana_trial_0.144:	Patron[144]@   23:	El venue tenia 10 personas y ahora 9
# INFO:Malasana_trial_0.197:	Patron[197]@   23:	El venue tenia 24 personas y ahora 23
# INFO:Malasana_trial_0.756:	Patron[756]@   23:	Es mi hora de irme a casa
# INFO:Malasana_trial_0.1407:	Patron[1407]@   23:	El venue tenia 9 personas y ahora 8
# INFO:Malasana_trial_0.208:	Patron[208]@   23:	El venue tenia 3 personas y ahora 2
# INFO:Malasana_trial_0.800:	Patron[800]@   23:	El venue tenia 2 personas y ahora 1
# INFO:Malasana_trial_0.945:	Patron[945]@   23:	El venue tenia 1 personas y ahora 0
# INFO:Malasana_trial_0.1203:	Patron[1203]@   23:	No tenía bar. Me han debido hacer kick out
# INFO:Malasana_trial_0.1265:	Patron[1265]@   23:	El venue tenia 23 personas y ahora 22
# INFO:Malasana_trial_0.75:	Patron[75]@   23:	El venue tenia 6 personas y ahora 5
# INFO:Malasana_trial_0.392:	Patron[392]@   23:	Me peleo con 1080
# INFO:Malasana_trial_0.579:	Patron[579]@   23:	El venue tenia 5 personas y ahora 4
# INFO:Malasana_trial_0.1080:	Patron[1080]@   23:	El venue tenia 22 personas y ahora 21
# INFO:Malasana_trial_0.1252:	Patron[1252]@   23:	Me peleo con 651
# INFO:Malasana_trial_0.340:	Patron[340]@   23:	This member is going to change venue: 340
# INFO:Malasana_trial_0.340:	Patron[340]@   23:	Al final no pudimos cambiar a ninguno y nos quedamos en este
# INFO:Malasana_trial_0.Police:	Police[Police]@   23:	El The awesome pub #8 ha cerrado con 4 personas dentro
# INFO:Malasana_trial_0.Police:	Police[Police]@   23:	El The awesome pub #3 ha cerrado con 0 personas dentro
# INFO:Malasana_trial_0.Police:	Police[Police]@   23:	El The awesome pub #2 ha cerrado con 0 personas dentro
# INFO:Malasana_trial_0.Police:	Police[Police]@   23:	El The awesome pub #9 ha cerrado con 0 personas dentro
# INFO:Malasana_trial_0.Police:	Police[Police]@   23:	Kicking out the fight agents: 392
# INFO:Malasana_trial_0.392:	Patron[392]@   23:	El venue tenia 21 personas y ahora 20
# INFO:Malasana_trial_0.Police:	Police[Police]@   23:	Kicking out the fight agents: 651
# INFO:Malasana_trial_0.651:	Patron[651]@   23:	El venue tenia 20 personas y ahora 19
# INFO:Malasana_trial_0.Police:	Police[Police]@   23:	Kicking out the fight agents: 1252
# INFO:Malasana_trial_0.1252:	Patron[1252]@   23:	El venue tenia 19 personas y ahora 18
# INFO:Malasana_trial_0.60:	Patron[60]@   24:	This member is going to change venue: 60
# INFO:Malasana_trial_0.60:	Patron[60]@   24:	Al final no pudimos cambiar a ninguno y nos quedamos en este
# INFO:Malasana_trial_0.178:	Patron[178]@   24:	El venue tenia 4 personas y ahora 3
# INFO:Malasana_trial_0.186:	Patron[186]@   24:	El venue tenia 3 personas y ahora 2
# INFO:Malasana_trial_0.1164:	Patron[1164]@   24:	El venue tenia 2 personas y ahora 1
# INFO:Malasana_trial_0.514:	Patron[514]@   24:	El venue tenia 18 personas y ahora 17
# INFO:Malasana_trial_0.598:	Patron[598]@   24:	Es mi hora de irme a casa
# INFO:Malasana_trial_0.943:	Patron[943]@   24:	Es mi hora de irme a casa
# INFO:Malasana_trial_0.1113:	Patron[1113]@   24:	El venue tenia 17 personas y ahora 16
# INFO:Malasana_trial_0.70:	Patron[70]@   24:	This member is going to change venue: 70
# INFO:Malasana_trial_0.70:	Patron[70]@   24:	Al final no pudimos cambiar a ninguno y nos quedamos en este
# INFO:Malasana_trial_0.311:	Patron[311]@   24:	Me voy a casa porque habíamos salido 5 y solo quedamos 2
# INFO:Malasana_trial_0.599:	Patron[599]@   24:	El venue tenia 8 personas y ahora 7
# INFO:Malasana_trial_0.756:	Patron[756]@   24:	El venue tenia 5 personas y ahora 4
# INFO:Malasana_trial_0.22:	Patron[22]@   24:	Es mi hora de irme a casa
# INFO:Malasana_trial_0.46:	Patron[46]@   24:	El venue tenia 1 personas y ahora 0
# INFO:Malasana_trial_0.340:	Patron[340]@   24:	This member is going to change venue: 340
# INFO:Malasana_trial_0.340:	Patron[340]@   24:	Al final no pudimos cambiar a ninguno y nos quedamos en este
# INFO:Malasana_trial_0.36:	Patron[36]@   24:	This member is going to change venue: 36
# INFO:Malasana_trial_0.36:	Patron[36]@   24:	Al final no pudimos cambiar a ninguno y nos quedamos en este
# INFO:Malasana_trial_0.Police:	Police[Police]@   24:	El The awesome pub #1 ha cerrado con 7 personas dentro
# INFO:Malasana_trial_0.60:	Patron[60]@   25:	This member is going to change venue: 60
# INFO:Malasana_trial_0.60:	Patron[60]@   25:	Al final no pudimos cambiar a ninguno y nos quedamos en este
# INFO:Malasana_trial_0.1134:	Patron[1134]@   25:	Me peleo con 609
# INFO:Malasana_trial_0.251:	Patron[251]@   25:	Me voy a casa porque habíamos salido 13 y solo quedamos 6
# INFO:Malasana_trial_0.421:	Patron[421]@   25:	El venue tenia 16 personas y ahora 15
# INFO:Malasana_trial_0.598:	Patron[598]@   25:	El venue tenia 15 personas y ahora 14
# INFO:Malasana_trial_0.657:	Patron[657]@   25:	El venue tenia 14 personas y ahora 13
# INFO:Malasana_trial_0.943:	Patron[943]@   25:	El venue tenia 13 personas y ahora 12
# INFO:Malasana_trial_0.989:	Patron[989]@   25:	El venue tenia 12 personas y ahora 11
# INFO:Malasana_trial_0.70:	Patron[70]@   25:	Es mi hora de irme a casa
# INFO:Malasana_trial_0.311:	Patron[311]@   25:	El venue tenia 7 personas y ahora 6
# INFO:Malasana_trial_0.153:	Patron[153]@   25:	El venue tenia 11 personas y ahora 10
# INFO:Malasana_trial_0.158:	Patron[158]@   25:	Me voy a casa porque habíamos salido 10 y solo quedamos 5
# INFO:Malasana_trial_0.535:	Patron[535]@   25:	El venue tenia 10 personas y ahora 9
# INFO:Malasana_trial_0.607:	Patron[607]@   25:	El venue tenia 9 personas y ahora 8
# INFO:Malasana_trial_0.651:	Patron[651]@   25:	No tenía bar. Me han debido hacer kick out
# INFO:Malasana_trial_0.1354:	Patron[1354]@   25:	El venue tenia 8 personas y ahora 7
# INFO:Malasana_trial_0.22:	Patron[22]@   25:	El venue tenia 6 personas y ahora 5
# INFO:Malasana_trial_0.384:	Patron[384]@   25:	This member is going to change venue: 384
# INFO:Malasana_trial_0.384:	Patron[384]@   25:	Al final no pudimos cambiar a ninguno y nos quedamos en este
# INFO:Malasana_trial_0.392:	Patron[392]@   25:	No tenía bar. Me han debido hacer kick out
# INFO:Malasana_trial_0.1252:	Patron[1252]@   25:	No tenía bar. Me han debido hacer kick out
# INFO:Malasana_trial_0.340:	Patron[340]@   25:	This member is going to change venue: 340
# INFO:Malasana_trial_0.340:	Patron[340]@   25:	Al final no pudimos cambiar a ninguno y nos quedamos en este
# INFO:Malasana_trial_0.36:	Patron[36]@   25:	This member is going to change venue: 36
# INFO:Malasana_trial_0.36:	Patron[36]@   25:	Nuestro plan se nos ha acabado
# INFO:Malasana_trial_0.268:	Patron[268]@   25:	El venue tenia 4 personas y ahora 3
# INFO:Malasana_trial_0.471:	Patron[471]@   25:	El venue tenia 3 personas y ahora 2
# INFO:Malasana_trial_0.1092:	Patron[1092]@   25:	El venue tenia 2 personas y ahora 1
# INFO:Malasana_trial_0.Police:	Police[Police]@   25:	Kicking out the fight agents: 609
# INFO:Malasana_trial_0.609:	Patron[609]@   25:	El venue tenia 6 personas y ahora 5
# INFO:Malasana_trial_0.Police:	Police[Police]@   25:	Kicking out the fight agents: 1134
# INFO:Malasana_trial_0.1134:	Patron[1134]@   25:	El venue tenia 5 personas y ahora 4
# INFO:Malasana_trial_0.60:	Patron[60]@   26:	This member is going to change venue: 60
# INFO:Malasana_trial_0.60:	Patron[60]@   26:	Nuestro plan se nos ha acabado
# INFO:Malasana_trial_0.274:	Patron[274]@   26:	El venue tenia 4 personas y ahora 3
# INFO:Malasana_trial_0.1065:	Patron[1065]@   26:	El venue tenia 3 personas y ahora 2
# INFO:Malasana_trial_0.1134:	Patron[1134]@   26:	No tenía bar. Me han debido hacer kick out
# INFO:Malasana_trial_0.251:	Patron[251]@   26:	El venue tenia 7 personas y ahora 6
# INFO:Malasana_trial_0.70:	Patron[70]@   26:	El venue tenia 4 personas y ahora 3
# INFO:Malasana_trial_0.215:	Patron[215]@   26:	Me voy a casa porque habíamos salido 6 y solo quedamos 3
# INFO:Malasana_trial_0.1110:	Patron[1110]@   26:	El venue tenia 3 personas y ahora 2
# INFO:Malasana_trial_0.1247:	Patron[1247]@   26:	El venue tenia 2 personas y ahora 1
# INFO:Malasana_trial_0.158:	Patron[158]@   26:	El venue tenia 6 personas y ahora 5
# INFO:Malasana_trial_0.384:	Patron[384]@   26:	Es mi hora de irme a casa
# INFO:Malasana_trial_0.1158:	Patron[1158]@   26:	El venue tenia 5 personas y ahora 4
# INFO:Malasana_trial_0.609:	Patron[609]@   26:	No tenía bar. Me han debido hacer kick out
# INFO:Malasana_trial_0.36:	Patron[36]@   26:	El venue tenia 1 personas y ahora 0
# INFO:Malasana_trial_0.60:	Patron[60]@   27:	El venue tenia 2 personas y ahora 1
# INFO:Malasana_trial_0.215:	Patron[215]@   27:	El venue tenia 1 personas y ahora 0
# INFO:Malasana_trial_0.384:	Patron[384]@   27:	El venue tenia 5 personas y ahora 4
# INFO:Malasana_trial_0.1051:	Patron[1051]@   27:	Es mi hora de irme a casa
# INFO:Malasana_trial_0.1470:	Patron[1470]@   27:	Es mi hora de irme a casa
# INFO:Malasana_trial_0.340:	Patron[340]@   27:	El venue tenia 1 personas y ahora 0
# INFO:Malasana_trial_0.338:	Patron[338]@   28:	This member is going to change venue: 338
# INFO:Malasana_trial_0.338:	Patron[338]@   28:	Al final no pudimos cambiar a ninguno y nos quedamos en este
# INFO:Malasana_trial_0.748:	Patron[748]@   28:	Es mi hora de irme a casa
# INFO:Malasana_trial_0.1051:	Patron[1051]@   28:	El venue tenia 4 personas y ahora 3
# INFO:Malasana_trial_0.1470:	Patron[1470]@   28:	El venue tenia 4 personas y ahora 3
# INFO:Malasana_trial_0.1474:	Patron[1474]@   28:	Me voy a casa porque habíamos salido 7 y solo quedamos 3
# INFO:Malasana_trial_0.8:	Patron[8] @   29:	El venue tenia 3 personas y ahora 2
# INFO:Malasana_trial_0.338:	Patron[338]@   29:	Es mi hora de irme a casa
# INFO:Malasana_trial_0.695:	Patron[695]@   29:	Es mi hora de irme a casa
# INFO:Malasana_trial_0.748:	Patron[748]@   29:	El venue tenia 2 personas y ahora 1
# INFO:Malasana_trial_0.1301:	Patron[1301]@   29:	Me voy a casa porque habíamos salido 6 y solo quedamos 3
# INFO:Malasana_trial_0.1474:	Patron[1474]@   29:	El venue tenia 1 personas y ahora 0
# INFO:Malasana_trial_0.338:	Patron[338]@   30:	El venue tenia 3 personas y ahora 2
# INFO:Malasana_trial_0.695:	Patron[695]@   30:	El venue tenia 2 personas y ahora 1
# INFO:Malasana_trial_0.1301:	Patron[1301]@   30:	El venue tenia 1 personas y ahora 0
# INFO:Malasana_trial_0.Police:	Police[Police]@   36:	El The awesome disco #0 ha cerrado con 0 personas dentro
# INFO:soil:Environment stats:
# agents:
#   model_count: {}
#   state_count: {}
# network:
#   n_edges: 0
#   n_nodes: 0
# params:
#   SEED: NoneMalasana_trial_0
#   pubs:
#     'The awesome disco #0':
#       capacity: 1017.3993832699213
#       closing_time: 36
#       entry: 3000
#       name: 'The awesome disco #0'
#       occupancy: 0
#       open: false
#       opening_time: 10
#       price: 9
#       type: disco
#     'The awesome pub #0':
#       capacity: 106.63346730070982
#       closing_time: 20
#       entry: 3000
#       name: 'The awesome pub #0'
#       occupancy: 0
#       open: false
#       opening_time: 1
#       price: 7
#       type: pub
#     'The awesome pub #1':
#       capacity: 100.67283446707194
#       closing_time: 24
#       entry: 3000
#       name: 'The awesome pub #1'
#       occupancy: 0
#       open: false
#       opening_time: 1
#       price: 7
#       type: pub
#     'The awesome pub #2':
#       capacity: 109.4224481976463
#       closing_time: 23
#       entry: 3000
#       name: 'The awesome pub #2'
#       occupancy: 0
#       open: false
#       opening_time: 1
#       price: 5
#       type: pub
#     'The awesome pub #3':
#       capacity: 110.67434293979768
#       closing_time: 23
#       entry: 3000
#       name: 'The awesome pub #3'
#       occupancy: 0
#       open: false
#       opening_time: 1
#       price: 7
#       type: pub
#     'The awesome pub #4':
#       capacity: 48.55363565336951
#       closing_time: 21
#       entry: 3000
#       name: 'The awesome pub #4'
#       occupancy: 0
#       open: false
#       opening_time: 1
#       price: 7
#       type: pub
#     'The awesome pub #5':
#       capacity: 102.32646812256512
#       closing_time: 20
#       entry: 3000
#       name: 'The awesome pub #5'
#       occupancy: 0
#       open: false
#       opening_time: 1
#       price: 7
#       type: pub
#     'The awesome pub #6':
#       capacity: 93.23602020424855
#       closing_time: 20
#       entry: 3000
#       name: 'The awesome pub #6'
#       occupancy: 0
#       open: false
#       opening_time: 1
#       price: 5
#       type: pub
#     'The awesome pub #7':
#       capacity: 102.75683747923262
#       closing_time: 22
#       entry: 3000
#       name: 'The awesome pub #7'
#       occupancy: 0
#       open: false
#       opening_time: 1
#       price: 7
#       type: pub
#     'The awesome pub #8':
#       capacity: 112.5339121267704
#       closing_time: 23
#       entry: 3000
#       name: 'The awesome pub #8'
#       occupancy: 0
#       open: false
#       opening_time: 1
#       price: 6
#       type: pub
#     'The awesome pub #9':
#       capacity: 118.30206982465643
#       closing_time: 23
#       entry: 3000
#       name: 'The awesome pub #9'
#       occupancy: 0
#       open: false
#       opening_time: 1
#       price: 7
#       type: pub
#     'The awesome street #0':
#       capacity: 10000
#       closing_time: 39
#       entry: 0
#       name: 'The awesome street #0'
#       occupancy: 0
#       open: true
#       opening_time: 1
#       price: 5
#       type: street
#
# INFO:soil:Finished Simulation Malasana trial 0 at 18:32:48 in 181.05288171768188 seconds
# INFO:soil:Dumping results to soil_output/Malasana
# INFO:soil:Finished simulation Malasana at 18:32:48 in 220.66900491714478 seconds

# %%
x = numpy.random.poisson(20, 20000000)
print(x)
count, bins, ignored = plt.hist(x, 14, normed=True)
plt.show()
# Out:
# [22 13 20 ... 20 26 13]
# /home/alberto/.local/lib/python3.5/site-packages/matplotlib/axes/_axes.py:6571: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
x = numpy.random.gamma(3.456,0.026,20000)
print(x)
count, bins, ignored = plt.hist(x, 30, normed=True)
plt.show()
# Out:
# [0.0709327  0.18518663 0.14354343 ... 0.0954438  0.05053816 0.03000834]
# /home/alberto/.local/lib/python3.5/site-packages/matplotlib/axes/_axes.py:6571: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
# Out:
# [9.0, 7.0, 5.0, 6.0, 6.0, 5.0, 6.0, 4.0, 9.0, 8.0, 6.0, 6.0, 4.0, 6.0, 8.0, 8.0, 7.0, 7.0, 6.0, 7.0]
# /home/alberto/.local/lib/python3.5/site-packages/matplotlib/axes/_axes.py:6571: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
